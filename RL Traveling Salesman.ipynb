# %% [markdown]
# # RL Traveling Salesman
#
# In this notebook, we implement a reinforcement learning approach to the traveling salesman problem. It is based on Q-learning and structure2vec graph embeddings.

# %%
import numpy as np
import torch
import random
import math
from collections import namedtuple
import os
import time

from scipy.spatial import distance_matrix
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import connected_components

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from scipy.signal import medfilt

""" Note: the code is not optimized for GPU
"""
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Create Graph Instances
# Below we implement a small method to generate random graph instances.

# %%
def get_graph_mat(n=10, size=1):
    """ Throws n nodes uniformly at random on a square, and build a (fully connected) graph.
        Returns the (N, 2) coordinates matrix, and the (N, N) matrix containing pairwise euclidean distances.
    """
    coords = size * np.random.uniform(size=(n,2))
    dist_mat = distance_matrix(coords, coords)
    return coords, dist_mat

def plot_graph(coords, mat):
    """ Utility function to plot the fully connected graph
    """
    n = len(coords)
    
    plt.scatter(coords[:,0], coords[:,1], s=[50 for _ in range(n)])
    for i in range(n):
        for j in range(n):
            if j < i:
                plt.plot([coords[i,0], coords[j,0]], [coords[i,1], coords[j,1]], 'b', alpha=0.7)

# %%
coords, W_np = get_graph_mat(n=10)
plot_graph(coords, W_np)

# %% [markdown]
# ## Define the state
# We now define the state tuple, containing a graph (given by a weights matrix `W`), the noode coordinates `coords` and the partial solution (list of visited nodes).
# We also define the function `state2tens`, which translates such tuples into tensors (partially loosing the sequence order information).

# %%
State = namedtuple('State', ('W', 'coords', 'partial_solution'))
  
def state2tens(state):
    """ Creates a Pytorch tensor representing the history of visited nodes, from a (single) state tuple.
        
        Returns a (Nx5) tensor, where for each node we store whether this node is in the sequence,
        whether it is first or last, and its (x,y) coordinates.
    """
    solution = set(state.partial_solution)
    sol_last_node = state.partial_solution[-1] if len(state.partial_solution) > 0 else -1
    sol_first_node = state.partial_solution[0] if len(state.partial_solution) > 0 else -1
    coords = state.coords
    nr_nodes = coords.shape[0]

    xv = [[(1 if i in solution else 0),
           (1 if i == sol_first_node else 0),
           (1 if i == sol_last_node else 0),
           coords[i,0],
           coords[i,1]
          ] for i in range(nr_nodes)]
    
    return torch.tensor(xv, dtype=torch.float32, requires_grad=False, device=device)

# %% [markdown]
# ## The Q-Function
# Below, we write the neural network that will parameterize the function Q(s, a).

# %%
class QNet(nn.Module):
    """ The neural net that will parameterize the function Q(s, a)
    
        The input is the state (containing the graph and visited nodes),
        and the output is a vector of size N containing Q(s, a) for each of the N actions a.
    """    
    
    def __init__(self, emb_dim, T=4):
        """ emb_dim: embedding dimension p
            T: number of iterations for the graph embedding
        """
        super(QNet, self).__init__()
        self.emb_dim = emb_dim
        self.T = T
        
        # We use 5 dimensions for representing the nodes' states:
        # * A binary variable indicating whether the node has been visited
        # * A binary variable indicating whether the node is the first of the visited sequence
        # * A binary variable indicating whether the node is the last of the visited sequence
        # * The (x, y) coordinates of the node.
        self.node_dim = 5
        
        # We can have an extra layer after theta_1 (for the sake of example to make the network deeper)
        nr_extra_layers_1 = 1
        
        # Build the learnable affine maps:
        self.theta1 = nn.Linear(self.node_dim, self.emb_dim, True)
        self.theta2 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta3 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta4 = nn.Linear(1, self.emb_dim, True)
        self.theta5 = nn.Linear(2*self.emb_dim, 1, True)
        self.theta6 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta7 = nn.Linear(self.emb_dim, self.emb_dim, True)
        
        self.theta1_extras = [nn.Linear(self.emb_dim, self.emb_dim, True) for _ in range(nr_extra_layers_1)]
        
    def forward(self, xv, Ws):
        # xv: The node features (batch_size, num_nodes, node_dim)
        # Ws: The graphs (batch_size, num_nodes, num_nodes)
        
        num_nodes = xv.shape[1]
        batch_size = xv.shape[0]
        
        # pre-compute 1-0 connection matrices masks (batch_size, num_nodes, num_nodes)
        conn_matrices = torch.where(Ws > 0, torch.ones_like(Ws), torch.zeros_like(Ws)).to(device)
        
        # Graph embedding
        # Note: we first compute s1 and s3 once, as they are not dependent on mu
        mu = torch.zeros(batch_size, num_nodes, self.emb_dim, device=device)
        s1 = self.theta1(xv)  # (batch_size, num_nodes, emb_dim)
        for layer in self.theta1_extras:
            s1 = layer(F.relu(s1))  # we apply the extra layer
        
        s3_1 = F.relu(self.theta4(Ws.unsqueeze(3)))  # (batch_size, nr_nodes, nr_nodes, emb_dim) - each "weigth" is a p-dim vector        
        s3_2 = torch.sum(s3_1, dim=1)  # (batch_size, nr_nodes, emb_dim) - the embedding for each node
        s3 = self.theta3(s3_2)  # (batch_size, nr_nodes, emb_dim)
        
        for t in range(self.T):
            s2 = self.theta2(conn_matrices.matmul(mu))    
            mu = F.relu(s1 + s2 + s3)
            
        """ prediction
        """
        # we repeat the global state (summed over nodes) for each node, 
        # in order to concatenate it to local states later
        global_state = self.theta6(torch.sum(mu, dim=1, keepdim=True).repeat(1, num_nodes, 1))
        
        local_action = self.theta7(mu)  # (batch_dim, nr_nodes, emb_dim)
            
        out = F.relu(torch.cat([global_state, local_action], dim=2))
        return self.theta5(out).squeeze(dim=2)

# %%
""" See what the model returns
"""
model = QNet(3, T=1).to(device)
coords, W_np = get_graph_mat(n=10)
W = torch.tensor(W_np, dtype=torch.float32, device=device)
xv = torch.rand((1, W.shape[0], 5)).to(device) # random node state
Ws = W.unsqueeze(0)

y = model(xv, Ws)
print('model output: {}'.format(y))
# Out:
# model output: tensor([[1.6413, 1.5446, 1.6266, 1.5715, 1.5717, 1.5567, 1.6266, 1.6164, 1.6401,
#          1.6491]], grad_fn=<SqueezeBackward1>)

# %% [markdown]
# ### A wrapper around the neural net
# Below, we define the class `QFunction`, which will act as a wrapper around the neural net `QNet`, and can manipulate TSP (partial) solutions and translate them to tensors.

# %%
class QFunction():
    def __init__(self, model, optimizer, lr_scheduler):
        self.model = model  # The actual QNet
        self.optimizer = optimizer
        self.lr_scheduler = lr_scheduler
        self.loss_fn = nn.MSELoss()
    
    def predict(self, state_tsr, W):
        # batch of 1 - only called at inference time
        with torch.no_grad():
            estimated_rewards = self.model(state_tsr.unsqueeze(0), W.unsqueeze(0))
        return estimated_rewards[0]
                
    def get_best_action(self, state_tsr, state):
        """ Computes the best (greedy) action to take from a given state
            Returns a tuple containing the ID of the next node and the corresponding estimated reward
        """
        W = state.W
        estimated_rewards = self.predict(state_tsr, W)  # size (nr_nodes,)
        sorted_reward_idx = estimated_rewards.argsort(descending=True)
        
        solution = state.partial_solution
        
        already_in = set(solution)
        for idx in sorted_reward_idx.tolist():
            if (len(solution) == 0 or W[solution[-1], idx] > 0) and idx not in already_in:
                return idx, estimated_rewards[idx].item()
        
    def batch_update(self, states_tsrs, Ws, actions, targets):
        """ Take a gradient step using the loss computed on a batch of (states, Ws, actions, targets)
        
            states_tsrs: list of (single) state tensors
            Ws: list of W tensors
            actions: list of actions taken
            targets: list of targets (resulting estimated rewards after taking the actions)
        """        
        Ws_tsr = torch.stack(Ws).to(device)
        xv = torch.stack(states_tsrs).to(device)
        self.optimizer.zero_grad()
        
        # the rewards estimated by Q for the given actions
        estimated_rewards = self.model(xv, Ws_tsr)[range(len(actions)), actions]
        
        loss = self.loss_fn(estimated_rewards, torch.tensor(targets, device=device))
        loss_val = loss.item()
        
        loss.backward()
        self.optimizer.step()        
        self.lr_scheduler.step()
        
        return loss_val

# %% [markdown]
# ## Define experiences & memory
# We'll now a tuple representing an experience, and the memory that contains such experiences.
# An experience is composed of a (state, action) tuple, and the corresponding "next state" and reward. The "next state" can be N step after the "state" in the case of N-step Q-learning. In experiences, we save states both in their tuple and tensor representations, in order to avoid computing these somewhat expensive translations after the experience has been stored.
#
# The `Memory` class implements a memory of limited size.

# %%
# Note: we store state tensors in experience to compute these tensors only once later on
Experience = namedtuple('Experience', ('state', 'state_tsr', 'action', 'reward', 'next_state', 'next_state_tsr'))

class Memory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0
        self.nr_inserts = 0
        
    def remember(self, experience):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = experience
        self.position = (self.position + 1) % self.capacity
        self.nr_inserts += 1
        
    def sample_batch(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return min(self.nr_inserts, self.capacity)

# %% [markdown]
# ## Other useful things
# Below, we'll write a few more helper functions for computing solution length, deciding if a state is final and getting a next node at random from the graph.

# %%
def total_distance(solution, W):
    if len(solution) < 2:
        return 0  # there is no travel
    
    total_dist = 0
    for i in range(len(solution) - 1):
        total_dist += W[solution[i], solution[i+1]].item()
        
    # if this solution is "complete", go back to initial point
    if len(solution) == W.shape[0]:
        total_dist += W[solution[-1], solution[0]].item()

    return total_dist
        
def is_state_final(state):
    return len(set(state.partial_solution)) == state.W.shape[0]

def get_next_neighbor_random(state):
    solution, W = state.partial_solution, state.W
    
    if len(solution) == 0:
        return random.choice(range(W.shape[0]))
    already_in = set(solution)
    candidates = list(filter(lambda n: n.item() not in already_in, W[solution[-1]].nonzero()))
    if len(candidates) == 0:
        return None
    return random.choice(candidates).item()

# %% [markdown]
# ## Training Code
# ### Hyper-parameters

# %%
SEED = 1  # A seed for the random number generator

# Graph
NR_NODES = 10  # Number of nodes N
EMBEDDING_DIMENSIONS = 5  # Embedding dimension D
EMBEDDING_ITERATIONS_T = 1  # Number of embedding iterations T

# Learning
NR_EPISODES = 4001
MEMORY_CAPACITY = 10000
N_STEP_QL = 2  # Number of steps (n) in n-step Q-learning to wait before computing target reward estimate
BATCH_SIZE = 16

GAMMA = 0.9
INIT_LR = 5e-3
LR_DECAY_RATE = 1. - 2e-5  # learning rate decay

MIN_EPSILON = 0.1
EPSILON_DECAY_RATE = 6e-4  # epsilon decay

FOLDER_NAME = './models'  # where to checkpoint the best models

# %% [markdown]
# ### Model Initialization & checkpointing
# We will save our best models over the course of training - here we just define two functions for loading and checkpointing models

# %%
def init_model(fname=None):
    """ Create a new model. If fname is defined, load the model from the specified file.
    """
    Q_net = QNet(EMBEDDING_DIMENSIONS, T=EMBEDDING_ITERATIONS_T).to(device)
    optimizer = optim.Adam(Q_net.parameters(), lr=INIT_LR)
    lr_scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=LR_DECAY_RATE)
    
    if fname is not None:
        checkpoint = torch.load(fname)
        Q_net.load_state_dict(checkpoint['model'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        lr_scheduler.load_state_dict(checkpoint['lr_scheduler'])
    
    Q_func = QFunction(Q_net, optimizer, lr_scheduler)
    return Q_func, Q_net, optimizer, lr_scheduler

def checkpoint_model(model, optimizer, lr_scheduler, loss, 
                     episode, avg_length):
    if not os.path.exists(FOLDER_NAME):
        os.makedirs(FOLDER_NAME)
    
    fname = os.path.join(FOLDER_NAME, 'ep_{}'.format(episode))
    fname += '_length_{}'.format(avg_length)
    fname += '.tar'
    
    torch.save({
        'episode': episode,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'lr_scheduler': lr_scheduler.state_dict(),
        'loss': loss,
        'avg_length': avg_length
    }, fname)

# %% [markdown]
# ### Training Loop
# The code below is slightly more complex than the version appearing in the blog article. Notably, here in several places we maintain states represented both as tuples and tensors. We cache the tensor versions in order to avoid re-computing them many times. Also different from the article, the version below implements a version of n-step Q-learning, it checkpoints the best models (according to the median path length), and prints some information.

# %%
# seed everything for reproducible results first:
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Create module, optimizer, LR scheduler, and Q-function
Q_func, Q_net, optimizer, lr_scheduler = init_model()

# Create memory
memory = Memory(MEMORY_CAPACITY)

# Storing metrics about training:
found_solutions = dict()  # episode --> (coords, W, solution)
losses = []
path_lengths = []

# keep track of median path length for model checkpointing
current_min_med_length = float('inf')

for episode in range(NR_EPISODES):
    # sample a new random graph
    coords, W_np = get_graph_mat(n=NR_NODES)
    W = torch.tensor(W_np, dtype=torch.float32, requires_grad=False, device=device)
    
    # current partial solution - a list of node index
    solution = [random.randint(0, NR_NODES-1)]
    
    # current state (tuple and tensor)
    current_state = State(partial_solution=solution, W=W, coords=coords)
    current_state_tsr = state2tens(current_state)
    
    # Keep track of some variables for insertion in replay memory:
    states = [current_state]
    states_tsrs = [current_state_tsr]  # we also keep the state tensors here (for efficiency)
    rewards = []
    actions = []
    
    # current value of epsilon
    epsilon = max(MIN_EPSILON, (1-EPSILON_DECAY_RATE)**episode)
    
    nr_explores = 0
    t = -1
    while not is_state_final(current_state):
        t += 1  # time step of this episode
        
        if epsilon >= random.random():
            # explore
            next_node = get_next_neighbor_random(current_state)
            nr_explores += 1
        else:
            # exploit
            next_node, est_reward = Q_func.get_best_action(current_state_tsr, current_state)
            if episode % 50 == 0:
                print('Ep {} | current sol: {} / next est reward: {}'.format(episode, solution, est_reward))
        
        next_solution = solution + [next_node]
        
        # reward observed for taking this step        
        reward = -(total_distance(next_solution, W) - total_distance(solution, W))
        
        next_state = State(partial_solution=next_solution, W=W, coords=coords)
        next_state_tsr = state2tens(next_state)
        
        # store rewards and states obtained along this episode:
        states.append(next_state)
        states_tsrs.append(next_state_tsr)
        rewards.append(reward)
        actions.append(next_node)
        
        # store our experience in memory, using n-step Q-learning:
        if len(solution) >= N_STEP_QL:
            memory.remember(Experience(state=states[-N_STEP_QL],
                                       state_tsr=states_tsrs[-N_STEP_QL],
                                       action=actions[-N_STEP_QL],
                                       reward=sum(rewards[-N_STEP_QL:]),
                                       next_state=next_state,
                                       next_state_tsr=next_state_tsr))
            
        if is_state_final(next_state):
            for n in range(1, N_STEP_QL):
                memory.remember(Experience(state=states[-n],
                                           state_tsr=states_tsrs[-n], 
                                           action=actions[-n], 
                                           reward=sum(rewards[-n:]), 
                                           next_state=next_state,
                                           next_state_tsr=next_state_tsr))
        
        # update state and current solution
        current_state = next_state
        current_state_tsr = next_state_tsr
        solution = next_solution
        
        # take a gradient step
        loss = None
        if len(memory) >= BATCH_SIZE and len(memory) >= 2000:
            experiences = memory.sample_batch(BATCH_SIZE)
            
            batch_states_tsrs = [e.state_tsr for e in experiences]
            batch_Ws = [e.state.W for e in experiences]
            batch_actions = [e.action for e in experiences]
            batch_targets = []
            
            for i, experience in enumerate(experiences):
                target = experience.reward
                if not is_state_final(experience.next_state):
                    _, best_reward = Q_func.get_best_action(experience.next_state_tsr, 
                                                            experience.next_state)
                    target += GAMMA * best_reward
                batch_targets.append(target)
                
            # print('batch targets: {}'.format(batch_targets))
            loss = Q_func.batch_update(batch_states_tsrs, batch_Ws, batch_actions, batch_targets)
            losses.append(loss)
            
            """ Save model when we reach a new low average path length
            """
            med_length = np.median(path_lengths[-100:])
            if med_length < current_min_med_length:
                current_min_med_length = med_length
                checkpoint_model(Q_net, optimizer, lr_scheduler, loss, episode, med_length)
                
    length = total_distance(solution, W)
    path_lengths.append(length)

    if episode % 10 == 0:
        print('Ep %d. Loss = %.3f / median length = %.3f / last = %.4f / epsilon = %.4f / lr = %.4f' % (
            episode, (-1 if loss is None else loss), np.median(path_lengths[-50:]), length, epsilon,
            Q_func.optimizer.param_groups[0]['lr']))
        found_solutions[episode] = (W.clone(), coords.copy(), [n for n in solution])
# Out:
# Ep 0. Loss = -1.000 / median length = 3.487 / last = 3.4873 / epsilon = 1.0000 / lr = 0.0050
# Ep 10. Loss = -1.000 / median length = 5.717 / last = 5.7169 / epsilon = 0.9940 / lr = 0.0050
# Ep 20. Loss = -1.000 / median length = 4.974 / last = 4.3185 / epsilon = 0.9881 / lr = 0.0050
# Ep 30. Loss = -1.000 / median length = 4.974 / last = 3.7427 / epsilon = 0.9822 / lr = 0.0050
# Ep 40. Loss = -1.000 / median length = 4.974 / last = 5.0773 / epsilon = 0.9763 / lr = 0.0050
# Ep 50 | current sol: [8, 5] / next est reward: 0.03770823031663895
# Ep 50 | current sol: [8, 5, 7, 4] / next est reward: 0.10300276428461075
# Ep 50. Loss = -1.000 / median length = 5.000 / last = 5.7980 / epsilon = 0.9704 / lr = 0.0050
# Ep 60. Loss = -1.000 / median length = 5.036 / last = 6.1192 / epsilon = 0.9646 / lr = 0.0050
# Ep 70. Loss = -1.000 / median length = 5.194 / last = 5.5106 / epsilon = 0.9589 / lr = 0.0050
# Ep 80. Loss = -1.000 / median length = 5.270 / last = 6.1859 / epsilon = 0.9531 / lr = 0.0050
# Ep 90. Loss = -1.000 / median length = 5.423 / last = 4.1432 / epsilon = 0.9474 / lr = 0.0050
# Ep 100 | current sol: [2, 5] / next est reward: 0.05864334851503372
# Ep 100. Loss = -1.000 / median length = 5.438 / last = 5.6594 / epsilon = 0.9417 / lr = 0.0050
# Ep 110. Loss = -1.000 / median length = 5.260 / last = 5.4424 / epsilon = 0.9361 / lr = 0.0050
# Ep 120. Loss = -1.000 / median length = 5.248 / last = 5.1267 / epsilon = 0.9305 / lr = 0.0050
# Ep 130. Loss = -1.000 / median length = 5.110 / last = 5.0265 / epsilon = 0.9249 / lr = 0.0050
# Ep 140. Loss = -1.000 / median length = 5.126 / last = 6.8115 / epsilon = 0.9194 / lr = 0.0050
# Ep 150 | current sol: [2, 9, 5, 1, 8, 4, 0] / next est reward: 0.17410320043563843
# Ep 150. Loss = -1.000 / median length = 5.092 / last = 6.6586 / epsilon = 0.9139 / lr = 0.0050
# Ep 160. Loss = -1.000 / median length = 5.175 / last = 4.8218 / epsilon = 0.9084 / lr = 0.0050
# Ep 170. Loss = -1.000 / median length = 5.267 / last = 6.2621 / epsilon = 0.9030 / lr = 0.0050
# Ep 180. Loss = -1.000 / median length = 5.322 / last = 4.9805 / epsilon = 0.8976 / lr = 0.0050
# Ep 190. Loss = -1.000 / median length = 5.322 / last = 5.8369 / epsilon = 0.8922 / lr = 0.0050
# Ep 200 | current sol: [0, 8, 7, 6, 4, 2, 1, 3] / next est reward: 0.2636284828186035
# Ep 200. Loss = -1.000 / median length = 5.386 / last = 4.1729 / epsilon = 0.8869 / lr = 0.0050
# Ep 210. Loss = -1.000 / median length = 5.353 / last = 5.3736 / epsilon = 0.8816 / lr = 0.0050
# Ep 220. Loss = -1.000 / median length = 5.373 / last = 5.4645 / epsilon = 0.8763 / lr = 0.0050
# Ep 230. Loss = 1.530 / median length = 5.387 / last = 5.7456 / epsilon = 0.8711 / lr = 0.0050
# Ep 240. Loss = 0.307 / median length = 5.249 / last = 4.4279 / epsilon = 0.8659 / lr = 0.0050
# Ep 250 | current sol: [3, 7] / next est reward: -6.310578346252441
# Ep 250. Loss = 0.102 / median length = 5.010 / last = 5.4373 / epsilon = 0.8607 / lr = 0.0050
# Ep 260. Loss = 0.145 / median length = 5.010 / last = 5.7680 / epsilon = 0.8555 / lr = 0.0050
# Ep 270. Loss = 0.121 / median length = 4.907 / last = 4.4324 / epsilon = 0.8504 / lr = 0.0050
# Ep 280. Loss = 0.234 / median length = 4.873 / last = 4.2769 / epsilon = 0.8453 / lr = 0.0049
# Ep 290. Loss = 0.107 / median length = 4.938 / last = 6.0861 / epsilon = 0.8403 / lr = 0.0049
# Ep 300. Loss = 0.220 / median length = 5.006 / last = 5.0578 / epsilon = 0.8352 / lr = 0.0049
# Ep 310. Loss = 0.124 / median length = 5.015 / last = 7.2335 / epsilon = 0.8302 / lr = 0.0049
# Ep 320. Loss = 0.089 / median length = 5.149 / last = 5.2851 / epsilon = 0.8253 / lr = 0.0049
# Ep 330. Loss = 0.521 / median length = 5.211 / last = 4.4904 / epsilon = 0.8203 / lr = 0.0049
# Ep 340. Loss = 0.398 / median length = 5.077 / last = 4.5899 / epsilon = 0.8154 / lr = 0.0049
# Ep 350 | current sol: [4, 3, 0, 1] / next est reward: -7.446510314941406
# Ep 350 | current sol: [4, 3, 0, 1, 9, 7, 5] / next est reward: -4.481555461883545
# Ep 350. Loss = 0.136 / median length = 5.160 / last = 4.4163 / epsilon = 0.8105 / lr = 0.0049
# Ep 360. Loss = 0.214 / median length = 5.014 / last = 4.2053 / epsilon = 0.8057 / lr = 0.0049
# Ep 370. Loss = 0.153 / median length = 4.891 / last = 4.1855 / epsilon = 0.8009 / lr = 0.0049
# Ep 380. Loss = 0.171 / median length = 4.945 / last = 4.5907 / epsilon = 0.7961 / lr = 0.0049
# Ep 390. Loss = 0.236 / median length = 4.964 / last = 5.0496 / epsilon = 0.7913 / lr = 0.0049
# Ep 400 | current sol: [1, 3] / next est reward: -9.130134582519531
# Ep 400 | current sol: [1, 3, 5, 8, 9, 4, 6, 2, 7] / next est reward: -2.4972128868103027
# Ep 400. Loss = 0.086 / median length = 5.048 / last = 4.3465 / epsilon = 0.7866 / lr = 0.0048
# Ep 410. Loss = 0.076 / median length = 5.006 / last = 4.9777 / epsilon = 0.7819 / lr = 0.0048
# Ep 420. Loss = 0.140 / median length = 5.042 / last = 6.0914 / epsilon = 0.7772 / lr = 0.0048
# Ep 430. Loss = 0.287 / median length = 5.188 / last = 5.1669 / epsilon = 0.7725 / lr = 0.0048
# Ep 440. Loss = 0.323 / median length = 5.183 / last = 4.5960 / epsilon = 0.7679 / lr = 0.0048
# Ep 450 | current sol: [1, 5, 3] / next est reward: -9.28045654296875
# Ep 450 | current sol: [1, 5, 3, 0] / next est reward: -8.221210479736328
# Ep 450 | current sol: [1, 5, 3, 0, 4] / next est reward: -7.2714972496032715
# Ep 450 | current sol: [1, 5, 3, 0, 4, 9, 7] / next est reward: -5.708124160766602
# Ep 450 | current sol: [1, 5, 3, 0, 4, 9, 7, 2] / next est reward: -4.675013065338135
# Ep 450. Loss = 0.164 / median length = 5.163 / last = 4.7102 / epsilon = 0.7633 / lr = 0.0048
# Ep 460. Loss = 0.152 / median length = 5.184 / last = 4.6909 / epsilon = 0.7588 / lr = 0.0048
# Ep 470. Loss = 0.169 / median length = 5.129 / last = 5.1002 / epsilon = 0.7542 / lr = 0.0048
# Ep 480. Loss = 0.269 / median length = 4.971 / last = 3.8314 / epsilon = 0.7497 / lr = 0.0048
# Ep 490. Loss = 0.340 / median length = 5.038 / last = 3.5654 / epsilon = 0.7452 / lr = 0.0048
# Ep 500 | current sol: [8, 4, 9] / next est reward: -8.525269508361816
# Ep 500 | current sol: [8, 4, 9, 5] / next est reward: -7.692477226257324
# Ep 500 | current sol: [8, 4, 9, 5, 7] / next est reward: -6.7859673500061035
# Ep 500 | current sol: [8, 4, 9, 5, 7, 0] / next est reward: -5.94395112991333
# Ep 500. Loss = 0.199 / median length = 4.886 / last = 5.7910 / epsilon = 0.7408 / lr = 0.0048
# Ep 510. Loss = 0.321 / median length = 4.902 / last = 5.7822 / epsilon = 0.7363 / lr = 0.0047
# Ep 520. Loss = 0.227 / median length = 4.902 / last = 5.2320 / epsilon = 0.7319 / lr = 0.0047
# Ep 530. Loss = 0.163 / median length = 4.842 / last = 4.2919 / epsilon = 0.7275 / lr = 0.0047
# Ep 540. Loss = 0.128 / median length = 4.889 / last = 5.4303 / epsilon = 0.7232 / lr = 0.0047
# Ep 550 | current sol: [1, 5] / next est reward: -10.219427108764648
# Ep 550 | current sol: [1, 5, 3, 6, 0, 7, 4, 9, 2] / next est reward: -2.709223985671997
# Ep 550. Loss = 0.158 / median length = 4.849 / last = 6.3826 / epsilon = 0.7189 / lr = 0.0047
# Ep 560. Loss = 0.344 / median length = 4.944 / last = 4.5558 / epsilon = 0.7146 / lr = 0.0047
# Ep 570. Loss = 0.298 / median length = 4.827 / last = 4.4302 / epsilon = 0.7103 / lr = 0.0047
# Ep 580. Loss = 0.370 / median length = 4.827 / last = 4.7313 / epsilon = 0.7060 / lr = 0.0047
# Ep 590. Loss = 0.122 / median length = 4.943 / last = 5.1256 / epsilon = 0.7018 / lr = 0.0047
# Ep 600 | current sol: [1, 0, 8, 2, 9] / next est reward: -7.142920017242432
# Ep 600 | current sol: [1, 0, 8, 2, 9, 3, 5] / next est reward: -4.898179054260254
# Ep 600. Loss = 0.175 / median length = 5.048 / last = 5.6196 / epsilon = 0.6976 / lr = 0.0047
# Ep 610. Loss = 0.208 / median length = 5.083 / last = 4.9909 / epsilon = 0.6934 / lr = 0.0047
# Ep 620. Loss = 0.183 / median length = 5.133 / last = 4.5665 / epsilon = 0.6893 / lr = 0.0047
# Ep 630. Loss = 0.255 / median length = 5.191 / last = 3.4866 / epsilon = 0.6852 / lr = 0.0046
# Ep 640. Loss = 0.382 / median length = 5.245 / last = 4.8984 / epsilon = 0.6811 / lr = 0.0046
# Ep 650 | current sol: [5, 2, 4, 6, 1] / next est reward: -6.436933994293213
# Ep 650 | current sol: [5, 2, 4, 6, 1, 0] / next est reward: -5.662495136260986
# Ep 650 | current sol: [5, 2, 4, 6, 1, 0, 8] / next est reward: -5.168828010559082
# Ep 650. Loss = 0.261 / median length = 5.229 / last = 4.3830 / epsilon = 0.6770 / lr = 0.0046
# Ep 660. Loss = 0.249 / median length = 5.213 / last = 5.8532 / epsilon = 0.6729 / lr = 0.0046
# Ep 670. Loss = 0.145 / median length = 5.103 / last = 6.2493 / epsilon = 0.6689 / lr = 0.0046
# Ep 680. Loss = 0.145 / median length = 5.011 / last = 5.8318 / epsilon = 0.6649 / lr = 0.0046
# Ep 690. Loss = 0.221 / median length = 4.948 / last = 5.6095 / epsilon = 0.6609 / lr = 0.0046
# Ep 700 | current sol: [3, 8, 9, 6, 0, 5, 7] / next est reward: -3.7721405029296875
# Ep 700. Loss = 0.091 / median length = 5.011 / last = 3.6804 / epsilon = 0.6570 / lr = 0.0046
# Ep 710. Loss = 0.205 / median length = 4.971 / last = 3.5965 / epsilon = 0.6530 / lr = 0.0046
# Ep 720. Loss = 0.205 / median length = 4.990 / last = 4.2336 / epsilon = 0.6491 / lr = 0.0046
# Ep 730. Loss = 0.255 / median length = 5.076 / last = 5.2155 / epsilon = 0.6452 / lr = 0.0046
# Ep 740. Loss = 0.139 / median length = 5.213 / last = 5.8797 / epsilon = 0.6414 / lr = 0.0046
# Ep 750 | current sol: [3, 5] / next est reward: -8.338567733764648
# Ep 750 | current sol: [3, 5, 6, 7] / next est reward: -6.472219467163086
# Ep 750 | current sol: [3, 5, 6, 7, 4, 2] / next est reward: -4.823209762573242
# Ep 750 | current sol: [3, 5, 6, 7, 4, 2, 8] / next est reward: -4.160035133361816
# Ep 750. Loss = 0.158 / median length = 5.123 / last = 4.1507 / epsilon = 0.6375 / lr = 0.0045
# Ep 760. Loss = 0.152 / median length = 5.213 / last = 4.8043 / epsilon = 0.6337 / lr = 0.0045
# Ep 770. Loss = 0.138 / median length = 5.219 / last = 4.4968 / epsilon = 0.6299 / lr = 0.0045
# Ep 780. Loss = 0.201 / median length = 5.252 / last = 5.2526 / epsilon = 0.6262 / lr = 0.0045
# Ep 790. Loss = 0.118 / median length = 5.169 / last = 4.0519 / epsilon = 0.6224 / lr = 0.0045
# Ep 800 | current sol: [3, 8, 1] / next est reward: -8.408123016357422
# Ep 800 | current sol: [3, 8, 1, 2, 7, 9] / next est reward: -6.016373157501221
# Ep 800. Loss = 0.311 / median length = 5.268 / last = 6.0307 / epsilon = 0.6187 / lr = 0.0045
# Ep 810. Loss = 0.222 / median length = 5.268 / last = 6.2894 / epsilon = 0.6150 / lr = 0.0045
# Ep 820. Loss = 0.230 / median length = 5.268 / last = 6.6956 / epsilon = 0.6113 / lr = 0.0045
# Ep 830. Loss = 0.170 / median length = 5.197 / last = 5.3559 / epsilon = 0.6077 / lr = 0.0045
# Ep 840. Loss = 0.069 / median length = 5.155 / last = 6.3520 / epsilon = 0.6040 / lr = 0.0045
# Ep 850 | current sol: [1, 8] / next est reward: -8.762245178222656
# Ep 850 | current sol: [1, 8, 6, 0] / next est reward: -7.344676494598389
# Ep 850 | current sol: [1, 8, 6, 0, 4, 2, 3] / next est reward: -4.946096897125244
# Ep 850 | current sol: [1, 8, 6, 0, 4, 2, 3, 9] / next est reward: -3.904374599456787
# Ep 850. Loss = 0.254 / median length = 5.114 / last = 5.9132 / epsilon = 0.6004 / lr = 0.0045
# Ep 860. Loss = 0.214 / median length = 5.170 / last = 4.7639 / epsilon = 0.5968 / lr = 0.0045
# Ep 870. Loss = 0.158 / median length = 5.136 / last = 4.7188 / epsilon = 0.5932 / lr = 0.0044
# Ep 880. Loss = 0.214 / median length = 5.248 / last = 6.2741 / epsilon = 0.5897 / lr = 0.0044
# Ep 890. Loss = 0.220 / median length = 5.281 / last = 5.5964 / epsilon = 0.5862 / lr = 0.0044
# Ep 900 | current sol: [7, 3] / next est reward: -8.71895980834961
# Ep 900 | current sol: [7, 3, 5] / next est reward: -7.9143757820129395
# Ep 900 | current sol: [7, 3, 5, 2, 0, 4, 6] / next est reward: -4.731880187988281
# Ep 900 | current sol: [7, 3, 5, 2, 0, 4, 6, 1] / next est reward: -4.183627605438232
# Ep 900. Loss = 0.110 / median length = 5.281 / last = 4.7225 / epsilon = 0.5827 / lr = 0.0044
# Ep 910. Loss = 0.137 / median length = 4.908 / last = 4.8123 / epsilon = 0.5792 / lr = 0.0044
# Ep 920. Loss = 0.208 / median length = 4.717 / last = 3.0978 / epsilon = 0.5757 / lr = 0.0044
# Ep 930. Loss = 0.176 / median length = 4.704 / last = 6.3661 / epsilon = 0.5723 / lr = 0.0044
# Ep 940. Loss = 0.186 / median length = 4.769 / last = 5.9384 / epsilon = 0.5688 / lr = 0.0044
# Ep 950 | current sol: [8, 7, 5, 6] / next est reward: -6.847165584564209
# Ep 950 | current sol: [8, 7, 5, 6, 0] / next est reward: -6.352375507354736
# Ep 950 | current sol: [8, 7, 5, 6, 0, 9, 3] / next est reward: -4.716315269470215
# Ep 950 | current sol: [8, 7, 5, 6, 0, 9, 3, 4] / next est reward: -4.020593643188477
# Ep 950 | current sol: [8, 7, 5, 6, 0, 9, 3, 4, 1] / next est reward: -3.045376777648926
# Ep 950. Loss = 0.120 / median length = 4.774 / last = 5.0287 / epsilon = 0.5654 / lr = 0.0044
# Ep 960. Loss = 0.162 / median length = 4.722 / last = 4.3345 / epsilon = 0.5620 / lr = 0.0044
# Ep 970. Loss = 0.565 / median length = 4.845 / last = 4.7390 / epsilon = 0.5587 / lr = 0.0044
# Ep 980. Loss = 0.212 / median length = 5.007 / last = 5.2532 / epsilon = 0.5553 / lr = 0.0044
# Ep 990. Loss = 0.105 / median length = 4.784 / last = 5.4469 / epsilon = 0.5520 / lr = 0.0044
# Ep 1000 | current sol: [9] / next est reward: -8.971582412719727
# Ep 1000 | current sol: [9, 6, 5, 2] / next est reward: -6.286678314208984
# Ep 1000 | current sol: [9, 6, 5, 2, 7] / next est reward: -5.525269031524658
# Ep 1000 | current sol: [9, 6, 5, 2, 7, 3] / next est reward: -4.845580577850342
# Ep 1000. Loss = 0.105 / median length = 4.784 / last = 5.4143 / epsilon = 0.5487 / lr = 0.0043
# Ep 1010. Loss = 0.147 / median length = 4.798 / last = 4.8577 / epsilon = 0.5454 / lr = 0.0043
# Ep 1020. Loss = 0.197 / median length = 4.784 / last = 4.1803 / epsilon = 0.5422 / lr = 0.0043
# Ep 1030. Loss = 0.100 / median length = 4.770 / last = 5.3348 / epsilon = 0.5389 / lr = 0.0043
# Ep 1040. Loss = 0.175 / median length = 4.945 / last = 6.2168 / epsilon = 0.5357 / lr = 0.0043
# Ep 1050 | current sol: [5, 0] / next est reward: -7.786185264587402
# Ep 1050 | current sol: [5, 0, 1, 9] / next est reward: -6.212050914764404
# Ep 1050 | current sol: [5, 0, 1, 9, 6] / next est reward: -5.414033889770508
# Ep 1050 | current sol: [5, 0, 1, 9, 6, 8, 2, 3] / next est reward: -3.2193667888641357
# Ep 1050. Loss = 0.131 / median length = 4.968 / last = 4.9746 / epsilon = 0.5325 / lr = 0.0043
# Ep 1060. Loss = 0.115 / median length = 5.075 / last = 3.6949 / epsilon = 0.5293 / lr = 0.0043
# Ep 1070. Loss = 0.107 / median length = 5.097 / last = 4.4473 / epsilon = 0.5261 / lr = 0.0043
# Ep 1080. Loss = 0.065 / median length = 5.097 / last = 4.7869 / epsilon = 0.5230 / lr = 0.0043
# Ep 1090. Loss = 0.068 / median length = 5.122 / last = 3.6596 / epsilon = 0.5199 / lr = 0.0043
# Ep 1100 | current sol: [9, 6, 4] / next est reward: -7.869539260864258
# Ep 1100 | current sol: [9, 6, 4, 2, 3] / next est reward: -6.445309162139893
# Ep 1100 | current sol: [9, 6, 4, 2, 3, 0] / next est reward: -5.617898941040039
# Ep 1100 | current sol: [9, 6, 4, 2, 3, 0, 5] / next est reward: -4.977480888366699
# Ep 1100. Loss = 0.246 / median length = 5.211 / last = 4.3389 / epsilon = 0.5167 / lr = 0.0043
# Ep 1110. Loss = 0.166 / median length = 5.153 / last = 4.4828 / epsilon = 0.5137 / lr = 0.0043
# Ep 1120. Loss = 0.148 / median length = 5.001 / last = 4.1283 / epsilon = 0.5106 / lr = 0.0043
# Ep 1130. Loss = 0.268 / median length = 4.933 / last = 5.2534 / epsilon = 0.5075 / lr = 0.0042
# Ep 1140. Loss = 0.220 / median length = 4.780 / last = 4.8588 / epsilon = 0.5045 / lr = 0.0042
# Ep 1150 | current sol: [2] / next est reward: -8.81432056427002
# Ep 1150 | current sol: [2, 3] / next est reward: -7.802183628082275
# Ep 1150 | current sol: [2, 3, 4] / next est reward: -7.005045413970947
# Ep 1150 | current sol: [2, 3, 4, 6] / next est reward: -6.159158706665039
# Ep 1150. Loss = 0.148 / median length = 4.810 / last = 5.1378 / epsilon = 0.5015 / lr = 0.0042
# Ep 1160. Loss = 0.135 / median length = 4.810 / last = 4.6575 / epsilon = 0.4985 / lr = 0.0042
# Ep 1170. Loss = 0.206 / median length = 4.777 / last = 3.9275 / epsilon = 0.4955 / lr = 0.0042
# Ep 1180. Loss = 0.269 / median length = 4.922 / last = 5.5556 / epsilon = 0.4925 / lr = 0.0042
# Ep 1190. Loss = 0.223 / median length = 4.999 / last = 5.8920 / epsilon = 0.4896 / lr = 0.0042
# Ep 1200 | current sol: [2, 8] / next est reward: -8.377213478088379
# Ep 1200 | current sol: [2, 8, 4] / next est reward: -7.763876438140869
# Ep 1200 | current sol: [2, 8, 4, 1] / next est reward: -7.0600175857543945
# Ep 1200 | current sol: [2, 8, 4, 1, 0] / next est reward: -6.413201332092285
# Ep 1200 | current sol: [2, 8, 4, 1, 0, 6] / next est reward: -5.952457904815674
# Ep 1200 | current sol: [2, 8, 4, 1, 0, 6, 5] / next est reward: -5.261005878448486
# Ep 1200 | current sol: [2, 8, 4, 1, 0, 6, 5, 3, 9] / next est reward: -3.5087130069732666
# Ep 1200. Loss = 0.217 / median length = 4.966 / last = 4.1885 / epsilon = 0.4866 / lr = 0.0042
# Ep 1210. Loss = 0.096 / median length = 4.966 / last = 6.8240 / epsilon = 0.4837 / lr = 0.0042
# Ep 1220. Loss = 0.150 / median length = 4.993 / last = 5.8110 / epsilon = 0.4808 / lr = 0.0042
# Ep 1230. Loss = 0.318 / median length = 4.953 / last = 5.7648 / epsilon = 0.4780 / lr = 0.0042
# Ep 1240. Loss = 0.250 / median length = 5.019 / last = 4.1487 / epsilon = 0.4751 / lr = 0.0042
# Ep 1250 | current sol: [7] / next est reward: -6.806074142456055
# Ep 1250 | current sol: [7, 9, 5, 2] / next est reward: -4.861609935760498
# Ep 1250 | current sol: [7, 9, 5, 2, 3] / next est reward: -4.502224922180176
# Ep 1250 | current sol: [7, 9, 5, 2, 3, 4] / next est reward: -4.0719757080078125
# Ep 1250 | current sol: [7, 9, 5, 2, 3, 4, 8, 1] / next est reward: -2.7187576293945312
# Ep 1250 | current sol: [7, 9, 5, 2, 3, 4, 8, 1, 6] / next est reward: -2.4368486404418945
# Ep 1250. Loss = 0.155 / median length = 4.975 / last = 4.3288 / epsilon = 0.4723 / lr = 0.0042
# Ep 1260. Loss = 0.285 / median length = 4.768 / last = 4.5610 / epsilon = 0.4694 / lr = 0.0041
# Ep 1270. Loss = 0.171 / median length = 5.015 / last = 5.4909 / epsilon = 0.4666 / lr = 0.0041
# Ep 1280. Loss = 0.266 / median length = 5.015 / last = 4.1170 / epsilon = 0.4638 / lr = 0.0041
# Ep 1290. Loss = 0.155 / median length = 5.042 / last = 3.7519 / epsilon = 0.4611 / lr = 0.0041
# Ep 1300 | current sol: [6, 5] / next est reward: -7.362732887268066
# Ep 1300 | current sol: [6, 5, 9] / next est reward: -6.761009216308594
# Ep 1300 | current sol: [6, 5, 9, 4, 0, 3] / next est reward: -4.903868198394775
# Ep 1300 | current sol: [6, 5, 9, 4, 0, 3, 1, 8, 7] / next est reward: -2.8039019107818604
# Ep 1300. Loss = 0.265 / median length = 5.135 / last = 5.1897 / epsilon = 0.4583 / lr = 0.0041
# Ep 1310. Loss = 0.294 / median length = 5.222 / last = 4.3168 / epsilon = 0.4556 / lr = 0.0041
# Ep 1320. Loss = 0.125 / median length = 5.165 / last = 2.2267 / epsilon = 0.4528 / lr = 0.0041
# Ep 1330. Loss = 0.222 / median length = 5.165 / last = 4.5189 / epsilon = 0.4501 / lr = 0.0041
# Ep 1340. Loss = 0.287 / median length = 5.165 / last = 2.8026 / epsilon = 0.4474 / lr = 0.0041
# Ep 1350 | current sol: [7, 0] / next est reward: -8.16444206237793
# Ep 1350 | current sol: [7, 0, 4] / next est reward: -7.27509069442749
# Ep 1350 | current sol: [7, 0, 4, 9, 3] / next est reward: -6.064550876617432
# Ep 1350 | current sol: [7, 0, 4, 9, 3, 8, 6] / next est reward: -4.66211462020874
# Ep 1350 | current sol: [7, 0, 4, 9, 3, 8, 6, 2] / next est reward: -4.278378963470459
# Ep 1350 | current sol: [7, 0, 4, 9, 3, 8, 6, 2, 5] / next est reward: -3.3232192993164062
# Ep 1350. Loss = 0.183 / median length = 4.980 / last = 6.1093 / epsilon = 0.4447 / lr = 0.0041
# Ep 1360. Loss = 0.267 / median length = 4.757 / last = 3.9938 / epsilon = 0.4421 / lr = 0.0041
# Ep 1370. Loss = 0.196 / median length = 5.186 / last = 6.1115 / epsilon = 0.4394 / lr = 0.0041
# Ep 1380. Loss = 0.262 / median length = 5.186 / last = 4.8320 / epsilon = 0.4368 / lr = 0.0041
# Ep 1390. Loss = 0.134 / median length = 5.104 / last = 5.4132 / epsilon = 0.4342 / lr = 0.0041
# Ep 1400 | current sol: [6] / next est reward: -8.330558776855469
# Ep 1400 | current sol: [6, 8, 0] / next est reward: -6.99736213684082
# Ep 1400 | current sol: [6, 8, 0, 1] / next est reward: -6.072379112243652
# Ep 1400 | current sol: [6, 8, 0, 1, 5, 7, 9, 2] / next est reward: -3.465611219406128
# Ep 1400. Loss = 0.112 / median length = 5.190 / last = 5.5917 / epsilon = 0.4316 / lr = 0.0040
# Ep 1410. Loss = 0.250 / median length = 5.190 / last = 5.6066 / epsilon = 0.4290 / lr = 0.0040
# Ep 1420. Loss = 0.367 / median length = 5.044 / last = 4.2527 / epsilon = 0.4265 / lr = 0.0040
# Ep 1430. Loss = 0.393 / median length = 5.013 / last = 4.5417 / epsilon = 0.4239 / lr = 0.0040
# Ep 1440. Loss = 0.130 / median length = 5.039 / last = 4.3396 / epsilon = 0.4214 / lr = 0.0040
# Ep 1450 | current sol: [3] / next est reward: -8.498473167419434
# Ep 1450 | current sol: [3, 6] / next est reward: -7.816592216491699
# Ep 1450 | current sol: [3, 6, 7] / next est reward: -7.280568599700928
# Ep 1450 | current sol: [3, 6, 7, 0] / next est reward: -6.679385185241699
# Ep 1450 | current sol: [3, 6, 7, 0, 8, 4] / next est reward: -5.1602630615234375
# Ep 1450 | current sol: [3, 6, 7, 0, 8, 4, 9, 5, 1] / next est reward: -2.848233222961426
# Ep 1450. Loss = 0.203 / median length = 4.919 / last = 4.8075 / epsilon = 0.4188 / lr = 0.0040
# Ep 1460. Loss = 0.152 / median length = 4.980 / last = 6.3377 / epsilon = 0.4163 / lr = 0.0040
# Ep 1470. Loss = 0.057 / median length = 5.060 / last = 4.1664 / epsilon = 0.4138 / lr = 0.0040
# Ep 1480. Loss = 0.085 / median length = 5.026 / last = 5.7301 / epsilon = 0.4114 / lr = 0.0040
# Ep 1490. Loss = 0.135 / median length = 5.030 / last = 5.0614 / epsilon = 0.4089 / lr = 0.0040
# Ep 1500 | current sol: [2, 4, 8] / next est reward: -6.868949890136719
# Ep 1500 | current sol: [2, 4, 8, 7] / next est reward: -6.481027126312256
# Ep 1500 | current sol: [2, 4, 8, 7, 9, 3, 1] / next est reward: -4.534398555755615
# Ep 1500 | current sol: [2, 4, 8, 7, 9, 3, 1, 0] / next est reward: -3.328933000564575
# Ep 1500. Loss = 0.101 / median length = 5.037 / last = 5.7096 / epsilon = 0.4065 / lr = 0.0040
# Ep 1510. Loss = 0.098 / median length = 4.949 / last = 4.7649 / epsilon = 0.4040 / lr = 0.0040
# Ep 1520. Loss = 0.150 / median length = 4.815 / last = 4.1880 / epsilon = 0.4016 / lr = 0.0040
# Ep 1530. Loss = 0.146 / median length = 4.980 / last = 5.1608 / epsilon = 0.3992 / lr = 0.0040
# Ep 1540. Loss = 0.093 / median length = 4.891 / last = 3.9460 / epsilon = 0.3968 / lr = 0.0039
# Ep 1550 | current sol: [1] / next est reward: -6.410771369934082
# Ep 1550 | current sol: [1, 8] / next est reward: -6.101787567138672
# Ep 1550 | current sol: [1, 8, 4, 5, 7, 2, 9, 3, 0] / next est reward: -1.6953048706054688
# Ep 1550. Loss = 0.061 / median length = 4.780 / last = 6.4313 / epsilon = 0.3944 / lr = 0.0039
# Ep 1560. Loss = 0.132 / median length = 4.766 / last = 5.5005 / epsilon = 0.3921 / lr = 0.0039
# Ep 1570. Loss = 0.120 / median length = 4.499 / last = 5.1690 / epsilon = 0.3897 / lr = 0.0039
# Ep 1580. Loss = 0.084 / median length = 4.499 / last = 4.4075 / epsilon = 0.3874 / lr = 0.0039
# Ep 1590. Loss = 0.088 / median length = 4.442 / last = 4.2329 / epsilon = 0.3851 / lr = 0.0039
# Ep 1600 | current sol: [6, 7, 8, 9, 2, 0, 1] / next est reward: -4.1550140380859375
# Ep 1600 | current sol: [6, 7, 8, 9, 2, 0, 1, 5] / next est reward: -3.260117530822754
# Ep 1600. Loss = 0.094 / median length = 4.561 / last = 4.2229 / epsilon = 0.3828 / lr = 0.0039
# Ep 1610. Loss = 0.071 / median length = 4.861 / last = 4.9437 / epsilon = 0.3805 / lr = 0.0039
# Ep 1620. Loss = 0.104 / median length = 4.966 / last = 5.1693 / epsilon = 0.3782 / lr = 0.0039
# Ep 1630. Loss = 0.093 / median length = 5.153 / last = 5.8420 / epsilon = 0.3760 / lr = 0.0039
# Ep 1640. Loss = 0.103 / median length = 5.310 / last = 5.7815 / epsilon = 0.3737 / lr = 0.0039
# Ep 1650 | current sol: [0, 7, 3] / next est reward: -7.063137054443359
# Ep 1650 | current sol: [0, 7, 3, 2] / next est reward: -6.623216152191162
# Ep 1650 | current sol: [0, 7, 3, 2, 8] / next est reward: -6.39619255065918
# Ep 1650 | current sol: [0, 7, 3, 2, 8, 1] / next est reward: -5.809378623962402
# Ep 1650 | current sol: [0, 7, 3, 2, 8, 1, 5] / next est reward: -4.973711967468262
# Ep 1650 | current sol: [0, 7, 3, 2, 8, 1, 5, 6] / next est reward: -4.35013484954834
# Ep 1650. Loss = 0.196 / median length = 5.006 / last = 3.9673 / epsilon = 0.3715 / lr = 0.0039
# Ep 1660. Loss = 0.133 / median length = 5.006 / last = 6.0256 / epsilon = 0.3692 / lr = 0.0039
# Ep 1670. Loss = 0.138 / median length = 4.626 / last = 3.6141 / epsilon = 0.3670 / lr = 0.0039
# Ep 1680. Loss = 0.150 / median length = 4.517 / last = 5.1702 / epsilon = 0.3648 / lr = 0.0038
# Ep 1690. Loss = 0.162 / median length = 4.697 / last = 5.6343 / epsilon = 0.3627 / lr = 0.0038
# Ep 1700 | current sol: [2, 5] / next est reward: -5.48932409286499
# Ep 1700 | current sol: [2, 5, 9] / next est reward: -5.45169734954834
# Ep 1700 | current sol: [2, 5, 9, 6] / next est reward: -5.376580238342285
# Ep 1700 | current sol: [2, 5, 9, 6, 3, 1] / next est reward: -5.141162395477295
# Ep 1700 | current sol: [2, 5, 9, 6, 3, 1, 4, 0, 7] / next est reward: -2.3334946632385254
# Ep 1700. Loss = 0.259 / median length = 4.916 / last = 4.1401 / epsilon = 0.3605 / lr = 0.0038
# Ep 1710. Loss = 0.112 / median length = 4.916 / last = 5.5731 / epsilon = 0.3583 / lr = 0.0038
# Ep 1720. Loss = 0.084 / median length = 4.948 / last = 4.2889 / epsilon = 0.3562 / lr = 0.0038
# Ep 1730. Loss = 0.070 / median length = 4.944 / last = 4.6310 / epsilon = 0.3541 / lr = 0.0038
# Ep 1740. Loss = 0.112 / median length = 4.931 / last = 5.3957 / epsilon = 0.3519 / lr = 0.0038
# Ep 1750 | current sol: [8] / next est reward: -7.1653289794921875
# Ep 1750 | current sol: [8, 1, 2, 4, 9, 3] / next est reward: -5.2271342277526855
# Ep 1750 | current sol: [8, 1, 2, 4, 9, 3, 6, 7] / next est reward: -3.33992075920105
# Ep 1750 | current sol: [8, 1, 2, 4, 9, 3, 6, 7, 5] / next est reward: -3.137730121612549
# Ep 1750. Loss = 0.115 / median length = 4.706 / last = 5.5514 / epsilon = 0.3498 / lr = 0.0038
# Ep 1760. Loss = 0.068 / median length = 4.706 / last = 4.0426 / epsilon = 0.3477 / lr = 0.0038
# Ep 1770. Loss = 0.101 / median length = 4.851 / last = 4.4446 / epsilon = 0.3457 / lr = 0.0038
# Ep 1780. Loss = 0.160 / median length = 4.942 / last = 5.4241 / epsilon = 0.3436 / lr = 0.0038
# Ep 1790. Loss = 0.145 / median length = 4.942 / last = 4.7423 / epsilon = 0.3415 / lr = 0.0038
# Ep 1800 | current sol: [7, 0, 2] / next est reward: -6.915637016296387
# Ep 1800 | current sol: [7, 0, 2, 6] / next est reward: -6.591184616088867
# Ep 1800 | current sol: [7, 0, 2, 6, 5] / next est reward: -6.268945693969727
# Ep 1800 | current sol: [7, 0, 2, 6, 5, 9] / next est reward: -5.848631858825684
# Ep 1800 | current sol: [7, 0, 2, 6, 5, 9, 8, 3] / next est reward: -3.502896785736084
# Ep 1800. Loss = 0.108 / median length = 4.885 / last = 4.1921 / epsilon = 0.3395 / lr = 0.0038
# Ep 1810. Loss = 0.083 / median length = 4.814 / last = 5.4696 / epsilon = 0.3375 / lr = 0.0038
# Ep 1820. Loss = 0.068 / median length = 4.814 / last = 4.3464 / epsilon = 0.3354 / lr = 0.0037
# Ep 1830. Loss = 0.182 / median length = 4.716 / last = 4.7668 / epsilon = 0.3334 / lr = 0.0037
# Ep 1840. Loss = 0.186 / median length = 4.838 / last = 5.7814 / epsilon = 0.3314 / lr = 0.0037
# Ep 1850 | current sol: [5, 1, 9] / next est reward: -7.589656829833984
# Ep 1850 | current sol: [5, 1, 9, 2] / next est reward: -7.352021217346191
# Ep 1850 | current sol: [5, 1, 9, 2, 4] / next est reward: -7.486383438110352
# Ep 1850 | current sol: [5, 1, 9, 2, 4, 8] / next est reward: -7.094269752502441
# Ep 1850 | current sol: [5, 1, 9, 2, 4, 8, 7] / next est reward: -6.352822303771973
# Ep 1850 | current sol: [5, 1, 9, 2, 4, 8, 7, 3] / next est reward: -4.870884895324707
# Ep 1850. Loss = 0.206 / median length = 4.915 / last = 4.9770 / epsilon = 0.3294 / lr = 0.0037
# Ep 1860. Loss = 0.106 / median length = 4.993 / last = 5.1373 / epsilon = 0.3275 / lr = 0.0037
# Ep 1870. Loss = 0.080 / median length = 4.946 / last = 4.8007 / epsilon = 0.3255 / lr = 0.0037
# Ep 1880. Loss = 0.208 / median length = 5.010 / last = 5.8049 / epsilon = 0.3236 / lr = 0.0037
# Ep 1890. Loss = 0.092 / median length = 4.864 / last = 3.4377 / epsilon = 0.3216 / lr = 0.0037
# Ep 1900 | current sol: [9, 2, 7, 1] / next est reward: -4.994368553161621
# Ep 1900 | current sol: [9, 2, 7, 1, 6] / next est reward: -4.587193012237549
# Ep 1900 | current sol: [9, 2, 7, 1, 6, 3] / next est reward: -4.074524879455566
# Ep 1900 | current sol: [9, 2, 7, 1, 6, 3, 5] / next est reward: -3.619253635406494
# Ep 1900 | current sol: [9, 2, 7, 1, 6, 3, 5, 4] / next est reward: -3.1601579189300537
# Ep 1900 | current sol: [9, 2, 7, 1, 6, 3, 5, 4, 8] / next est reward: -2.5759873390197754
# Ep 1900. Loss = 0.176 / median length = 4.738 / last = 4.3342 / epsilon = 0.3197 / lr = 0.0037
# Ep 1910. Loss = 0.108 / median length = 4.738 / last = 5.0567 / epsilon = 0.3178 / lr = 0.0037
# Ep 1920. Loss = 0.114 / median length = 4.731 / last = 4.7253 / epsilon = 0.3159 / lr = 0.0037
# Ep 1930. Loss = 0.117 / median length = 4.597 / last = 5.3387 / epsilon = 0.3140 / lr = 0.0037
# Ep 1940. Loss = 0.337 / median length = 4.580 / last = 4.5472 / epsilon = 0.3121 / lr = 0.0037
# Ep 1950 | current sol: [6] / next est reward: -8.618919372558594
# Ep 1950 | current sol: [6, 8, 0, 2, 4] / next est reward: -6.5360260009765625
# Ep 1950 | current sol: [6, 8, 0, 2, 4, 5, 3] / next est reward: -4.296717643737793
# Ep 1950 | current sol: [6, 8, 0, 2, 4, 5, 3, 7] / next est reward: -3.1138076782226562
# Ep 1950. Loss = 0.085 / median length = 4.676 / last = 6.4897 / epsilon = 0.3103 / lr = 0.0037
# Ep 1960. Loss = 0.082 / median length = 4.676 / last = 5.2153 / epsilon = 0.3084 / lr = 0.0037
# Ep 1970. Loss = 0.313 / median length = 4.676 / last = 5.3817 / epsilon = 0.3066 / lr = 0.0036
# Ep 1980. Loss = 0.131 / median length = 4.765 / last = 3.5867 / epsilon = 0.3047 / lr = 0.0036
# Ep 1990. Loss = 0.313 / median length = 5.016 / last = 3.6639 / epsilon = 0.3029 / lr = 0.0036
# Ep 2000 | current sol: [0] / next est reward: -8.491876602172852
# Ep 2000 | current sol: [0, 8] / next est reward: -8.12668228149414
# Ep 2000 | current sol: [0, 8, 2] / next est reward: -7.816884994506836
# Ep 2000 | current sol: [0, 8, 2, 4, 9] / next est reward: -6.6258463859558105
# Ep 2000 | current sol: [0, 8, 2, 4, 9, 1] / next est reward: -5.929267883300781
# Ep 2000 | current sol: [0, 8, 2, 4, 9, 1, 5, 7, 6] / next est reward: -2.4373157024383545
# Ep 2000. Loss = 0.187 / median length = 4.731 / last = 4.4688 / epsilon = 0.3011 / lr = 0.0036
# Ep 2010. Loss = 0.240 / median length = 4.750 / last = 4.7514 / epsilon = 0.2993 / lr = 0.0036
# Ep 2020. Loss = 0.056 / median length = 4.697 / last = 2.5510 / epsilon = 0.2975 / lr = 0.0036
# Ep 2030. Loss = 0.151 / median length = 4.671 / last = 5.2015 / epsilon = 0.2957 / lr = 0.0036
# Ep 2040. Loss = 0.184 / median length = 4.463 / last = 4.3686 / epsilon = 0.2939 / lr = 0.0036
# Ep 2050 | current sol: [8] / next est reward: -9.017773628234863
# Ep 2050 | current sol: [8, 6] / next est reward: -8.729357719421387
# Ep 2050 | current sol: [8, 6, 3, 0] / next est reward: -7.785126209259033
# Ep 2050 | current sol: [8, 6, 3, 0, 1] / next est reward: -7.285357475280762
# Ep 2050 | current sol: [8, 6, 3, 0, 1, 7] / next est reward: -6.832527160644531
# Ep 2050 | current sol: [8, 6, 3, 0, 1, 7, 2] / next est reward: -5.6123151779174805
# Ep 2050 | current sol: [8, 6, 3, 0, 1, 7, 2, 5] / next est reward: -4.336987495422363
# Ep 2050 | current sol: [8, 6, 3, 0, 1, 7, 2, 5, 4] / next est reward: -3.2348709106445312
# Ep 2050. Loss = 0.134 / median length = 4.675 / last = 5.2683 / epsilon = 0.2922 / lr = 0.0036
# Ep 2060. Loss = 0.148 / median length = 4.613 / last = 5.3822 / epsilon = 0.2904 / lr = 0.0036
# Ep 2070. Loss = 0.163 / median length = 4.725 / last = 5.4196 / epsilon = 0.2887 / lr = 0.0036
# Ep 2080. Loss = 0.129 / median length = 4.530 / last = 4.0151 / epsilon = 0.2870 / lr = 0.0036
# Ep 2090. Loss = 0.104 / median length = 4.580 / last = 4.9074 / epsilon = 0.2853 / lr = 0.0036
# Ep 2100 | current sol: [7] / next est reward: -7.832502365112305
# Ep 2100 | current sol: [7, 2] / next est reward: -7.636938095092773
# Ep 2100 | current sol: [7, 2, 5, 1] / next est reward: -7.166688442230225
# Ep 2100 | current sol: [7, 2, 5, 1, 4, 8] / next est reward: -5.8361711502075195
# Ep 2100 | current sol: [7, 2, 5, 1, 4, 8, 9] / next est reward: -5.1499857902526855
# Ep 2100 | current sol: [7, 2, 5, 1, 4, 8, 9, 3] / next est reward: -4.136763572692871
# Ep 2100. Loss = 0.212 / median length = 4.466 / last = 4.1439 / epsilon = 0.2835 / lr = 0.0036
# Ep 2110. Loss = 0.338 / median length = 4.455 / last = 4.3685 / epsilon = 0.2819 / lr = 0.0036
# Ep 2120. Loss = 0.208 / median length = 4.363 / last = 4.5875 / epsilon = 0.2802 / lr = 0.0036
# Ep 2130. Loss = 0.313 / median length = 4.488 / last = 6.6342 / epsilon = 0.2785 / lr = 0.0035
# Ep 2140. Loss = 0.159 / median length = 4.378 / last = 4.4883 / epsilon = 0.2768 / lr = 0.0035
# Ep 2150 | current sol: [4] / next est reward: -7.721859931945801
# Ep 2150 | current sol: [4, 2] / next est reward: -7.508319854736328
# Ep 2150 | current sol: [4, 2, 3] / next est reward: -7.409801006317139
# Ep 2150 | current sol: [4, 2, 3, 8, 5, 6] / next est reward: -5.419178009033203
# Ep 2150 | current sol: [4, 2, 3, 8, 5, 6, 9] / next est reward: -4.723047733306885
# Ep 2150 | current sol: [4, 2, 3, 8, 5, 6, 9, 0] / next est reward: -3.589818000793457
# Ep 2150 | current sol: [4, 2, 3, 8, 5, 6, 9, 0, 1] / next est reward: -2.516907215118408
# Ep 2150. Loss = 0.115 / median length = 4.378 / last = 3.6182 / epsilon = 0.2752 / lr = 0.0035
# Ep 2160. Loss = 0.159 / median length = 4.438 / last = 4.8766 / epsilon = 0.2735 / lr = 0.0035
# Ep 2170. Loss = 0.098 / median length = 4.492 / last = 3.9834 / epsilon = 0.2719 / lr = 0.0035
# Ep 2180. Loss = 0.173 / median length = 4.492 / last = 5.8286 / epsilon = 0.2703 / lr = 0.0035
# Ep 2190. Loss = 0.373 / median length = 4.508 / last = 3.6543 / epsilon = 0.2686 / lr = 0.0035
# Ep 2200 | current sol: [7] / next est reward: -6.234367370605469
# Ep 2200 | current sol: [7, 6] / next est reward: -6.116034984588623
# Ep 2200 | current sol: [7, 6, 3] / next est reward: -5.99126672744751
# Ep 2200 | current sol: [7, 6, 3, 5] / next est reward: -5.850769996643066
# Ep 2200 | current sol: [7, 6, 3, 5, 4] / next est reward: -5.603177547454834
# Ep 2200 | current sol: [7, 6, 3, 5, 4, 0, 9] / next est reward: -3.4879517555236816
# Ep 2200 | current sol: [7, 6, 3, 5, 4, 0, 9, 8] / next est reward: -3.5391621589660645
# Ep 2200. Loss = 0.062 / median length = 4.508 / last = 4.9232 / epsilon = 0.2670 / lr = 0.0035
# Ep 2210. Loss = 0.172 / median length = 4.536 / last = 3.7104 / epsilon = 0.2654 / lr = 0.0035
# Ep 2220. Loss = 0.159 / median length = 4.605 / last = 4.3044 / epsilon = 0.2638 / lr = 0.0035
# Ep 2230. Loss = 0.288 / median length = 4.395 / last = 6.2455 / epsilon = 0.2623 / lr = 0.0035
# Ep 2240. Loss = 0.180 / median length = 4.717 / last = 4.2410 / epsilon = 0.2607 / lr = 0.0035
# Ep 2250 | current sol: [9] / next est reward: -6.656367778778076
# Ep 2250 | current sol: [9, 6] / next est reward: -6.578794002532959
# Ep 2250 | current sol: [9, 6, 4] / next est reward: -6.443174362182617
# Ep 2250 | current sol: [9, 6, 4, 8] / next est reward: -6.1697797775268555
# Ep 2250 | current sol: [9, 6, 4, 8, 0, 7] / next est reward: -4.658425331115723
# Ep 2250 | current sol: [9, 6, 4, 8, 0, 7, 3] / next est reward: -4.002847671508789
# Ep 2250 | current sol: [9, 6, 4, 8, 0, 7, 3, 2] / next est reward: -3.101747989654541
# Ep 2250 | current sol: [9, 6, 4, 8, 0, 7, 3, 2, 5] / next est reward: -2.2774200439453125
# Ep 2250. Loss = 0.182 / median length = 4.503 / last = 5.1578 / epsilon = 0.2591 / lr = 0.0035
# Ep 2260. Loss = 0.289 / median length = 4.550 / last = 3.7749 / epsilon = 0.2576 / lr = 0.0035
# Ep 2270. Loss = 0.113 / median length = 4.731 / last = 5.0011 / epsilon = 0.2560 / lr = 0.0035
# Ep 2280. Loss = 0.333 / median length = 4.681 / last = 5.1980 / epsilon = 0.2545 / lr = 0.0035
# Ep 2290. Loss = 0.144 / median length = 4.542 / last = 3.3433 / epsilon = 0.2530 / lr = 0.0034
# Ep 2300 | current sol: [7] / next est reward: -9.321826934814453
# Ep 2300 | current sol: [7, 6, 8] / next est reward: -8.25903034210205
# Ep 2300 | current sol: [7, 6, 8, 3] / next est reward: -7.870625019073486
# Ep 2300 | current sol: [7, 6, 8, 3, 1] / next est reward: -7.635432720184326
# Ep 2300 | current sol: [7, 6, 8, 3, 1, 0] / next est reward: -7.163874626159668
# Ep 2300 | current sol: [7, 6, 8, 3, 1, 0, 5, 9] / next est reward: -4.150997161865234
# Ep 2300 | current sol: [7, 6, 8, 3, 1, 0, 5, 9, 4] / next est reward: -2.8611550331115723
# Ep 2300. Loss = 0.108 / median length = 4.681 / last = 5.6714 / epsilon = 0.2515 / lr = 0.0034
# Ep 2310. Loss = 0.253 / median length = 4.761 / last = 4.0846 / epsilon = 0.2500 / lr = 0.0034
# Ep 2320. Loss = 0.237 / median length = 4.595 / last = 4.2215 / epsilon = 0.2485 / lr = 0.0034
# Ep 2330. Loss = 0.314 / median length = 4.542 / last = 4.1048 / epsilon = 0.2470 / lr = 0.0034
# Ep 2340. Loss = 0.240 / median length = 4.650 / last = 4.3078 / epsilon = 0.2455 / lr = 0.0034
# Ep 2350 | current sol: [9] / next est reward: -8.13919448852539
# Ep 2350 | current sol: [9, 4, 0] / next est reward: -7.229852199554443
# Ep 2350 | current sol: [9, 4, 0, 5, 1] / next est reward: -6.618175506591797
# Ep 2350 | current sol: [9, 4, 0, 5, 1, 8] / next est reward: -6.390202522277832
# Ep 2350 | current sol: [9, 4, 0, 5, 1, 8, 6] / next est reward: -5.308657646179199
# Ep 2350 | current sol: [9, 4, 0, 5, 1, 8, 6, 7] / next est reward: -3.9930293560028076
# Ep 2350 | current sol: [9, 4, 0, 5, 1, 8, 6, 7, 3] / next est reward: -2.646544933319092
# Ep 2350. Loss = 0.074 / median length = 4.650 / last = 3.7375 / epsilon = 0.2440 / lr = 0.0034
# Ep 2360. Loss = 0.167 / median length = 4.650 / last = 3.8616 / epsilon = 0.2426 / lr = 0.0034
# Ep 2370. Loss = 0.370 / median length = 4.529 / last = 4.6844 / epsilon = 0.2411 / lr = 0.0034
# Ep 2380. Loss = 0.228 / median length = 4.513 / last = 4.3180 / epsilon = 0.2397 / lr = 0.0034
# Ep 2390. Loss = 0.186 / median length = 4.463 / last = 6.4346 / epsilon = 0.2383 / lr = 0.0034
# Ep 2400 | current sol: [9, 8] / next est reward: -7.29371976852417
# Ep 2400 | current sol: [9, 8, 5] / next est reward: -7.045330047607422
# Ep 2400 | current sol: [9, 8, 5, 4] / next est reward: -7.125528335571289
# Ep 2400 | current sol: [9, 8, 5, 4, 7] / next est reward: -6.900857925415039
# Ep 2400 | current sol: [9, 8, 5, 4, 7, 0] / next est reward: -6.374231815338135
# Ep 2400 | current sol: [9, 8, 5, 4, 7, 0, 3] / next est reward: -5.592890739440918
# Ep 2400 | current sol: [9, 8, 5, 4, 7, 0, 3, 6] / next est reward: -4.4377923011779785
# Ep 2400 | current sol: [9, 8, 5, 4, 7, 0, 3, 6, 2] / next est reward: -3.035877227783203
# Ep 2400. Loss = 0.293 / median length = 4.442 / last = 5.8423 / epsilon = 0.2368 / lr = 0.0034
# Ep 2410. Loss = 0.273 / median length = 4.469 / last = 6.3853 / epsilon = 0.2354 / lr = 0.0034
# Ep 2420. Loss = 0.227 / median length = 4.455 / last = 3.5523 / epsilon = 0.2340 / lr = 0.0034
# Ep 2430. Loss = 0.133 / median length = 4.446 / last = 4.8129 / epsilon = 0.2326 / lr = 0.0034
# Ep 2440. Loss = 0.195 / median length = 4.476 / last = 3.4468 / epsilon = 0.2312 / lr = 0.0034
# Ep 2450 | current sol: [1, 9] / next est reward: -8.320084571838379
# Ep 2450 | current sol: [1, 9, 0] / next est reward: -8.286964416503906
# Ep 2450 | current sol: [1, 9, 0, 2] / next est reward: -8.044883728027344
# Ep 2450 | current sol: [1, 9, 0, 2, 6] / next est reward: -7.745009422302246
# Ep 2450 | current sol: [1, 9, 0, 2, 6, 8] / next est reward: -7.2858476638793945
# Ep 2450 | current sol: [1, 9, 0, 2, 6, 8, 5] / next est reward: -6.001152992248535
# Ep 2450 | current sol: [1, 9, 0, 2, 6, 8, 5, 3, 4] / next est reward: -2.6387033462524414
# Ep 2450. Loss = 0.256 / median length = 4.446 / last = 4.0374 / epsilon = 0.2298 / lr = 0.0033
# Ep 2460. Loss = 0.119 / median length = 4.254 / last = 3.6738 / epsilon = 0.2284 / lr = 0.0033
# Ep 2470. Loss = 0.348 / median length = 4.203 / last = 4.2791 / epsilon = 0.2271 / lr = 0.0033
# Ep 2480. Loss = 0.245 / median length = 4.203 / last = 4.1471 / epsilon = 0.2257 / lr = 0.0033
# Ep 2490. Loss = 0.337 / median length = 4.193 / last = 4.0738 / epsilon = 0.2244 / lr = 0.0033
# Ep 2500 | current sol: [3] / next est reward: -7.6149115562438965
# Ep 2500 | current sol: [3, 6] / next est reward: -7.571077823638916
# Ep 2500 | current sol: [3, 6, 1] / next est reward: -7.2786126136779785
# Ep 2500 | current sol: [3, 6, 1, 7] / next est reward: -7.03151798248291
# Ep 2500 | current sol: [3, 6, 1, 7, 0, 8, 2, 4] / next est reward: -4.647698879241943
# Ep 2500 | current sol: [3, 6, 1, 7, 0, 8, 2, 4, 5] / next est reward: -3.8400325775146484
# Ep 2500. Loss = 0.278 / median length = 4.270 / last = 5.3862 / epsilon = 0.2230 / lr = 0.0033
# Ep 2510. Loss = 0.170 / median length = 4.262 / last = 4.4375 / epsilon = 0.2217 / lr = 0.0033
# Ep 2520. Loss = 0.329 / median length = 4.461 / last = 4.5566 / epsilon = 0.2204 / lr = 0.0033
# Ep 2530. Loss = 0.161 / median length = 4.534 / last = 4.3555 / epsilon = 0.2190 / lr = 0.0033
# Ep 2540. Loss = 0.227 / median length = 4.599 / last = 3.0878 / epsilon = 0.2177 / lr = 0.0033
# Ep 2550 | current sol: [7] / next est reward: -6.526752471923828
# Ep 2550 | current sol: [7, 2] / next est reward: -6.293626308441162
# Ep 2550 | current sol: [7, 2, 4] / next est reward: -6.256021976470947
# Ep 2550 | current sol: [7, 2, 4, 9] / next est reward: -6.021605491638184
# Ep 2550 | current sol: [7, 2, 4, 9, 0] / next est reward: -5.8209943771362305
# Ep 2550 | current sol: [7, 2, 4, 9, 0, 3, 8] / next est reward: -4.428740978240967
# Ep 2550 | current sol: [7, 2, 4, 9, 0, 3, 8, 6] / next est reward: -4.591722011566162
# Ep 2550 | current sol: [7, 2, 4, 9, 0, 3, 8, 6, 1] / next est reward: -3.0988614559173584
# Ep 2550. Loss = 0.167 / median length = 4.509 / last = 3.9355 / epsilon = 0.2164 / lr = 0.0033
# Ep 2560. Loss = 0.146 / median length = 4.574 / last = 4.6367 / epsilon = 0.2151 / lr = 0.0033
# Ep 2570. Loss = 0.159 / median length = 4.574 / last = 3.6408 / epsilon = 0.2139 / lr = 0.0033
# Ep 2580. Loss = 0.164 / median length = 4.158 / last = 3.5679 / epsilon = 0.2126 / lr = 0.0033
# Ep 2590. Loss = 0.328 / median length = 4.124 / last = 3.7571 / epsilon = 0.2113 / lr = 0.0033
# Ep 2600 | current sol: [2] / next est reward: -6.489882469177246
# Ep 2600 | current sol: [2, 1] / next est reward: -6.445353984832764
# Ep 2600 | current sol: [2, 1, 0, 8] / next est reward: -5.28400993347168
# Ep 2600 | current sol: [2, 1, 0, 8, 3] / next est reward: -4.9906721115112305
# Ep 2600 | current sol: [2, 1, 0, 8, 3, 5] / next est reward: -4.602898120880127
# Ep 2600 | current sol: [2, 1, 0, 8, 3, 5, 9, 7] / next est reward: -3.7827351093292236
# Ep 2600 | current sol: [2, 1, 0, 8, 3, 5, 9, 7, 6] / next est reward: -2.5446393489837646
# Ep 2600. Loss = 0.137 / median length = 4.180 / last = 4.5551 / epsilon = 0.2100 / lr = 0.0033
# Ep 2610. Loss = 0.130 / median length = 4.180 / last = 4.2627 / epsilon = 0.2088 / lr = 0.0033
# Ep 2620. Loss = 0.226 / median length = 4.264 / last = 4.6163 / epsilon = 0.2075 / lr = 0.0032
# Ep 2630. Loss = 0.203 / median length = 4.443 / last = 5.7796 / epsilon = 0.2063 / lr = 0.0032
# Ep 2640. Loss = 0.173 / median length = 4.454 / last = 5.0851 / epsilon = 0.2051 / lr = 0.0032
# Ep 2650 | current sol: [4] / next est reward: -5.257417678833008
# Ep 2650 | current sol: [4, 8] / next est reward: -5.374973773956299
# Ep 2650 | current sol: [4, 8, 9] / next est reward: -5.420326232910156
# Ep 2650 | current sol: [4, 8, 9, 2] / next est reward: -5.542994022369385
# Ep 2650 | current sol: [4, 8, 9, 2, 1] / next est reward: -5.479183673858643
# Ep 2650 | current sol: [4, 8, 9, 2, 1, 6] / next est reward: -4.856163024902344
# Ep 2650 | current sol: [4, 8, 9, 2, 1, 6, 5] / next est reward: -4.3038458824157715
# Ep 2650 | current sol: [4, 8, 9, 2, 1, 6, 5, 7] / next est reward: -3.525667905807495
# Ep 2650 | current sol: [4, 8, 9, 2, 1, 6, 5, 7, 3] / next est reward: -3.5599265098571777
# Ep 2650. Loss = 0.207 / median length = 4.351 / last = 3.0719 / epsilon = 0.2038 / lr = 0.0032
# Ep 2660. Loss = 0.140 / median length = 4.337 / last = 5.0039 / epsilon = 0.2026 / lr = 0.0032
# Ep 2670. Loss = 0.216 / median length = 4.329 / last = 4.6093 / epsilon = 0.2014 / lr = 0.0032
# Ep 2680. Loss = 0.403 / median length = 4.329 / last = 3.3890 / epsilon = 0.2002 / lr = 0.0032
# Ep 2690. Loss = 0.165 / median length = 4.320 / last = 2.8833 / epsilon = 0.1990 / lr = 0.0032
# Ep 2700 | current sol: [0] / next est reward: -7.214651107788086
# Ep 2700 | current sol: [0, 3] / next est reward: -7.211198806762695
# Ep 2700 | current sol: [0, 3, 9] / next est reward: -7.380589485168457
# Ep 2700 | current sol: [0, 3, 9, 4] / next est reward: -7.233805179595947
# Ep 2700 | current sol: [0, 3, 9, 4, 2] / next est reward: -7.593563079833984
# Ep 2700 | current sol: [0, 3, 9, 4, 2, 1, 5] / next est reward: -5.765237808227539
# Ep 2700 | current sol: [0, 3, 9, 4, 2, 1, 5, 8] / next est reward: -5.3993072509765625
# Ep 2700 | current sol: [0, 3, 9, 4, 2, 1, 5, 8, 6] / next est reward: -3.572326183319092
# Ep 2700. Loss = 0.415 / median length = 4.526 / last = 4.8464 / epsilon = 0.1978 / lr = 0.0032
# Ep 2710. Loss = 0.248 / median length = 4.411 / last = 5.8200 / epsilon = 0.1966 / lr = 0.0032
# Ep 2720. Loss = 0.391 / median length = 4.258 / last = 3.0501 / epsilon = 0.1954 / lr = 0.0032
# Ep 2730. Loss = 0.213 / median length = 4.314 / last = 4.5970 / epsilon = 0.1943 / lr = 0.0032
# Ep 2740. Loss = 0.155 / median length = 4.258 / last = 5.3675 / epsilon = 0.1931 / lr = 0.0032
# Ep 2750 | current sol: [4] / next est reward: -3.180706024169922
# Ep 2750 | current sol: [4, 6] / next est reward: -3.182114362716675
# Ep 2750 | current sol: [4, 6, 7] / next est reward: -3.077572822570801
# Ep 2750 | current sol: [4, 6, 7, 0, 8] / next est reward: -2.5474326610565186
# Ep 2750 | current sol: [4, 6, 7, 0, 8, 1] / next est reward: -2.8554742336273193
# Ep 2750 | current sol: [4, 6, 7, 0, 8, 1, 3] / next est reward: -2.7333474159240723
# Ep 2750 | current sol: [4, 6, 7, 0, 8, 1, 3, 9, 2] / next est reward: -1.6618894338607788
# Ep 2750. Loss = 0.336 / median length = 4.258 / last = 4.4391 / epsilon = 0.1920 / lr = 0.0032
# Ep 2760. Loss = 0.080 / median length = 4.241 / last = 3.9289 / epsilon = 0.1908 / lr = 0.0032
# Ep 2770. Loss = 0.081 / median length = 4.196 / last = 4.6710 / epsilon = 0.1897 / lr = 0.0032
# Ep 2780. Loss = 0.399 / median length = 4.055 / last = 5.3474 / epsilon = 0.1885 / lr = 0.0032
# Ep 2790. Loss = 0.206 / median length = 4.100 / last = 6.0061 / epsilon = 0.1874 / lr = 0.0031
# Ep 2800 | current sol: [9, 0] / next est reward: -5.599204063415527
# Ep 2800 | current sol: [9, 0, 5] / next est reward: -5.706868648529053
# Ep 2800 | current sol: [9, 0, 5, 1, 4] / next est reward: -5.113872528076172
# Ep 2800 | current sol: [9, 0, 5, 1, 4, 2] / next est reward: -4.783217430114746
# Ep 2800 | current sol: [9, 0, 5, 1, 4, 2, 6] / next est reward: -4.19546365737915
# Ep 2800 | current sol: [9, 0, 5, 1, 4, 2, 6, 8, 7] / next est reward: -2.869680881500244
# Ep 2800. Loss = 0.122 / median length = 4.017 / last = 4.5864 / epsilon = 0.1863 / lr = 0.0031
# Ep 2810. Loss = 0.271 / median length = 4.160 / last = 3.9096 / epsilon = 0.1852 / lr = 0.0031
# Ep 2820. Loss = 0.115 / median length = 4.273 / last = 3.9813 / epsilon = 0.1841 / lr = 0.0031
# Ep 2830. Loss = 0.139 / median length = 4.396 / last = 3.9078 / epsilon = 0.1830 / lr = 0.0031
# Ep 2840. Loss = 0.161 / median length = 4.460 / last = 4.3281 / epsilon = 0.1819 / lr = 0.0031
# Ep 2850 | current sol: [6] / next est reward: -5.972257137298584
# Ep 2850 | current sol: [6, 5] / next est reward: -5.83942174911499
# Ep 2850 | current sol: [6, 5, 1, 7, 9, 2, 0] / next est reward: -2.1034326553344727
# Ep 2850 | current sol: [6, 5, 1, 7, 9, 2, 0, 3] / next est reward: -2.109851837158203
# Ep 2850 | current sol: [6, 5, 1, 7, 9, 2, 0, 3, 4] / next est reward: -1.6502633094787598
# Ep 2850. Loss = 0.166 / median length = 4.508 / last = 4.8693 / epsilon = 0.1808 / lr = 0.0031
# Ep 2860. Loss = 0.174 / median length = 4.394 / last = 6.4431 / epsilon = 0.1797 / lr = 0.0031
# Ep 2870. Loss = 0.224 / median length = 4.364 / last = 4.5633 / epsilon = 0.1786 / lr = 0.0031
# Ep 2880. Loss = 0.143 / median length = 4.360 / last = 3.5507 / epsilon = 0.1775 / lr = 0.0031
# ...
# Ep 3300 | current sol: [2, 1, 4, 6, 5, 8, 9] / next est reward: -4.633927822113037
# Ep 3300 | current sol: [2, 1, 4, 6, 5, 8, 9, 7] / next est reward: -3.3817083835601807
# Ep 3300 | current sol: [2, 1, 4, 6, 5, 8, 9, 7, 0] / next est reward: -2.3121531009674072
# Ep 3300. Loss = 0.153 / median length = 4.004 / last = 4.0507 / epsilon = 0.1380 / lr = 0.0029
# Ep 3310. Loss = 0.099 / median length = 4.043 / last = 4.0362 / epsilon = 0.1372 / lr = 0.0029
# Ep 3320. Loss = 0.081 / median length = 4.048 / last = 4.9935 / epsilon = 0.1363 / lr = 0.0029
# Ep 3330. Loss = 0.114 / median length = 4.363 / last = 5.8100 / epsilon = 0.1355 / lr = 0.0029
# Ep 3340. Loss = 0.177 / median length = 4.363 / last = 4.2764 / epsilon = 0.1347 / lr = 0.0029
# Ep 3350 | current sol: [8] / next est reward: -4.609593868255615
# Ep 3350 | current sol: [8, 5] / next est reward: -4.633693695068359
# Ep 3350 | current sol: [8, 5, 9] / next est reward: -4.70396614074707
# Ep 3350 | current sol: [8, 5, 9, 4] / next est reward: -4.771993637084961
# Ep 3350 | current sol: [8, 5, 9, 4, 2, 7, 6] / next est reward: -2.8812012672424316
# Ep 3350 | current sol: [8, 5, 9, 4, 2, 7, 6, 1] / next est reward: -3.1192333698272705
# Ep 3350 | current sol: [8, 5, 9, 4, 2, 7, 6, 1, 0] / next est reward: -2.1394410133361816
# Ep 3350. Loss = 0.252 / median length = 4.407 / last = 5.6814 / epsilon = 0.1339 / lr = 0.0028
# Ep 3360. Loss = 0.163 / median length = 4.432 / last = 4.6001 / epsilon = 0.1331 / lr = 0.0028
# Ep 3370. Loss = 0.160 / median length = 4.504 / last = 4.2533 / epsilon = 0.1323 / lr = 0.0028
# Ep 3380. Loss = 0.160 / median length = 4.467 / last = 4.5271 / epsilon = 0.1315 / lr = 0.0028
# Ep 3390. Loss = 0.086 / median length = 4.498 / last = 4.4270 / epsilon = 0.1307 / lr = 0.0028
# Ep 3400 | current sol: [9] / next est reward: -2.360419750213623
# Ep 3400 | current sol: [9, 1, 5] / next est reward: -1.3878811597824097
# Ep 3400 | current sol: [9, 1, 5, 0] / next est reward: -1.3036527633666992
# Ep 3400 | current sol: [9, 1, 5, 0, 2] / next est reward: -1.193508267402649
# Ep 3400 | current sol: [9, 1, 5, 0, 2, 4] / next est reward: -1.1003422737121582
# Ep 3400 | current sol: [9, 1, 5, 0, 2, 4, 8] / next est reward: -1.0457391738891602
# Ep 3400 | current sol: [9, 1, 5, 0, 2, 4, 8, 3] / next est reward: -1.0006948709487915
# Ep 3400 | current sol: [9, 1, 5, 0, 2, 4, 8, 3, 7] / next est reward: -1.043198585510254
# Ep 3400. Loss = 0.154 / median length = 4.447 / last = 4.1271 / epsilon = 0.1299 / lr = 0.0028
# Ep 3410. Loss = 0.084 / median length = 4.467 / last = 4.7268 / epsilon = 0.1292 / lr = 0.0028
# Ep 3420. Loss = 0.191 / median length = 4.442 / last = 3.8257 / epsilon = 0.1284 / lr = 0.0028
# Ep 3430. Loss = 0.136 / median length = 4.447 / last = 4.8610 / epsilon = 0.1276 / lr = 0.0028
# Ep 3440. Loss = 0.206 / median length = 4.487 / last = 5.5085 / epsilon = 0.1269 / lr = 0.0028
# Ep 3450 | current sol: [1] / next est reward: -3.3146731853485107
# Ep 3450 | current sol: [1, 0] / next est reward: -3.380476951599121
# Ep 3450 | current sol: [1, 0, 4] / next est reward: -3.458101749420166
# Ep 3450 | current sol: [1, 0, 4, 6] / next est reward: -3.520498514175415
# Ep 3450 | current sol: [1, 0, 4, 6, 8] / next est reward: -3.5653200149536133
# Ep 3450 | current sol: [1, 0, 4, 6, 8, 9] / next est reward: -3.72503399848938
# Ep 3450 | current sol: [1, 0, 4, 6, 8, 9, 3] / next est reward: -3.6773643493652344
# Ep 3450 | current sol: [1, 0, 4, 6, 8, 9, 3, 5, 7] / next est reward: -2.8272204399108887
# Ep 3450. Loss = 0.094 / median length = 4.525 / last = 3.5097 / epsilon = 0.1261 / lr = 0.0028
# Ep 3460. Loss = 0.099 / median length = 4.385 / last = 3.8120 / epsilon = 0.1254 / lr = 0.0028
# Ep 3470. Loss = 0.119 / median length = 4.395 / last = 3.0857 / epsilon = 0.1246 / lr = 0.0028
# Ep 3480. Loss = 0.202 / median length = 4.347 / last = 5.2841 / epsilon = 0.1239 / lr = 0.0028
# Ep 3490. Loss = 0.172 / median length = 4.426 / last = 4.3091 / epsilon = 0.1231 / lr = 0.0028
# Ep 3500 | current sol: [4] / next est reward: -3.5834288597106934
# Ep 3500 | current sol: [4, 7] / next est reward: -3.702392578125
# Ep 3500 | current sol: [4, 7, 9] / next est reward: -3.9095115661621094
# Ep 3500 | current sol: [4, 7, 9, 3] / next est reward: -4.004775047302246
# Ep 3500 | current sol: [4, 7, 9, 3, 2] / next est reward: -3.808905601501465
# Ep 3500 | current sol: [4, 7, 9, 3, 2, 0] / next est reward: -3.7882747650146484
# Ep 3500 | current sol: [4, 7, 9, 3, 2, 0, 1] / next est reward: -3.524470806121826
# Ep 3500 | current sol: [4, 7, 9, 3, 2, 0, 1, 5] / next est reward: -3.260618209838867
# Ep 3500 | current sol: [4, 7, 9, 3, 2, 0, 1, 5, 6] / next est reward: -2.1593728065490723
# Ep 3500. Loss = 0.110 / median length = 4.426 / last = 4.2576 / epsilon = 0.1224 / lr = 0.0028
# Ep 3510. Loss = 0.128 / median length = 4.602 / last = 4.2868 / epsilon = 0.1216 / lr = 0.0028
# Ep 3520. Loss = 0.117 / median length = 4.668 / last = 3.5624 / epsilon = 0.1209 / lr = 0.0028
# Ep 3530. Loss = 0.116 / median length = 4.352 / last = 3.5794 / epsilon = 0.1202 / lr = 0.0028
# Ep 3540. Loss = 0.068 / median length = 4.289 / last = 3.4557 / epsilon = 0.1195 / lr = 0.0028
# Ep 3550 | current sol: [1] / next est reward: -4.140089988708496
# Ep 3550 | current sol: [1, 0] / next est reward: -4.204105377197266
# Ep 3550 | current sol: [1, 0, 9] / next est reward: -4.2591471672058105
# Ep 3550 | current sol: [1, 0, 9, 2] / next est reward: -4.352725982666016
# Ep 3550 | current sol: [1, 0, 9, 2, 5] / next est reward: -4.920448303222656
# Ep 3550 | current sol: [1, 0, 9, 2, 5, 4] / next est reward: -5.0458574295043945
# Ep 3550 | current sol: [1, 0, 9, 2, 5, 4, 3] / next est reward: -4.094010353088379
# Ep 3550 | current sol: [1, 0, 9, 2, 5, 4, 3, 6] / next est reward: -3.1235361099243164
# Ep 3550 | current sol: [1, 0, 9, 2, 5, 4, 3, 6, 8] / next est reward: -2.6557669639587402
# Ep 3550. Loss = 0.040 / median length = 4.289 / last = 4.1558 / epsilon = 0.1188 / lr = 0.0027
# Ep 3560. Loss = 0.122 / median length = 4.249 / last = 5.6367 / epsilon = 0.1181 / lr = 0.0027
# Ep 3570. Loss = 0.189 / median length = 4.284 / last = 3.3352 / epsilon = 0.1173 / lr = 0.0027
# Ep 3580. Loss = 0.140 / median length = 4.368 / last = 4.1400 / epsilon = 0.1166 / lr = 0.0027
# Ep 3590. Loss = 0.098 / median length = 4.420 / last = 4.4140 / epsilon = 0.1159 / lr = 0.0027
# Ep 3600 | current sol: [9] / next est reward: -3.79166841506958
# Ep 3600 | current sol: [9, 2] / next est reward: -3.8752799034118652
# Ep 3600 | current sol: [9, 2, 0] / next est reward: -3.9075591564178467
# Ep 3600 | current sol: [9, 2, 0, 8] / next est reward: -3.904694080352783
# Ep 3600 | current sol: [9, 2, 0, 8, 3] / next est reward: -3.7953808307647705
# Ep 3600 | current sol: [9, 2, 0, 8, 3, 7] / next est reward: -3.9409098625183105
# Ep 3600 | current sol: [9, 2, 0, 8, 3, 7, 6] / next est reward: -3.8622536659240723
# Ep 3600 | current sol: [9, 2, 0, 8, 3, 7, 6, 5] / next est reward: -2.993509292602539
# Ep 3600 | current sol: [9, 2, 0, 8, 3, 7, 6, 5, 4] / next est reward: -2.789193630218506
# Ep 3600. Loss = 0.216 / median length = 4.428 / last = 3.6600 / epsilon = 0.1153 / lr = 0.0027
# Ep 3610. Loss = 0.145 / median length = 4.354 / last = 4.1091 / epsilon = 0.1146 / lr = 0.0027
# Ep 3620. Loss = 0.104 / median length = 4.354 / last = 3.9241 / epsilon = 0.1139 / lr = 0.0027
# Ep 3630. Loss = 0.129 / median length = 4.443 / last = 4.4723 / epsilon = 0.1132 / lr = 0.0027
# Ep 3640. Loss = 0.166 / median length = 4.336 / last = 4.4810 / epsilon = 0.1125 / lr = 0.0027
# Ep 3650 | current sol: [5] / next est reward: -4.346140384674072
# Ep 3650 | current sol: [5, 4] / next est reward: -4.518171787261963
# Ep 3650 | current sol: [5, 4, 9] / next est reward: -4.601918697357178
# Ep 3650 | current sol: [5, 4, 9, 7] / next est reward: -4.693813323974609
# Ep 3650 | current sol: [5, 4, 9, 7, 6] / next est reward: -4.68762731552124
# Ep 3650 | current sol: [5, 4, 9, 7, 6, 1] / next est reward: -4.263782978057861
# Ep 3650 | current sol: [5, 4, 9, 7, 6, 1, 2] / next est reward: -3.6106643676757812
# Ep 3650 | current sol: [5, 4, 9, 7, 6, 1, 2, 3, 8] / next est reward: -1.9625731706619263
# Ep 3650. Loss = 0.245 / median length = 4.353 / last = 5.0437 / epsilon = 0.1118 / lr = 0.0027
# Ep 3660. Loss = 0.209 / median length = 4.441 / last = 4.6825 / epsilon = 0.1112 / lr = 0.0027
# Ep 3670. Loss = 0.189 / median length = 4.353 / last = 3.5148 / epsilon = 0.1105 / lr = 0.0027
# Ep 3680. Loss = 0.101 / median length = 4.286 / last = 5.2146 / epsilon = 0.1098 / lr = 0.0027
# Ep 3690. Loss = 0.184 / median length = 4.371 / last = 4.3671 / epsilon = 0.1092 / lr = 0.0027
# Ep 3700 | current sol: [5] / next est reward: -4.794802665710449
# Ep 3700 | current sol: [5, 8] / next est reward: -4.963899612426758
# Ep 3700 | current sol: [5, 8, 0] / next est reward: -5.252461910247803
# Ep 3700 | current sol: [5, 8, 0, 3] / next est reward: -5.379083633422852
# Ep 3700 | current sol: [5, 8, 0, 3, 6] / next est reward: -5.336387634277344
# Ep 3700 | current sol: [5, 8, 0, 3, 6, 1] / next est reward: -5.020917892456055
# Ep 3700 | current sol: [5, 8, 0, 3, 6, 1, 4] / next est reward: -4.451261043548584
# Ep 3700 | current sol: [5, 8, 0, 3, 6, 1, 4, 9] / next est reward: -3.526634454727173
# Ep 3700 | current sol: [5, 8, 0, 3, 6, 1, 4, 9, 2] / next est reward: -2.5684313774108887
# Ep 3700. Loss = 0.082 / median length = 4.412 / last = 4.3958 / epsilon = 0.1085 / lr = 0.0027
# Ep 3710. Loss = 0.140 / median length = 4.412 / last = 4.5530 / epsilon = 0.1079 / lr = 0.0027
# Ep 3720. Loss = 0.122 / median length = 4.394 / last = 3.2692 / epsilon = 0.1072 / lr = 0.0027
# Ep 3730. Loss = 0.107 / median length = 4.419 / last = 4.8711 / epsilon = 0.1066 / lr = 0.0027
# Ep 3740. Loss = 0.158 / median length = 4.419 / last = 4.1562 / epsilon = 0.1060 / lr = 0.0027
# Ep 3750 | current sol: [5] / next est reward: -4.311636447906494
# Ep 3750 | current sol: [5, 0] / next est reward: -4.412501811981201
# Ep 3750 | current sol: [5, 0, 2] / next est reward: -4.516820430755615
# Ep 3750 | current sol: [5, 0, 2, 9] / next est reward: -4.9705281257629395
# Ep 3750 | current sol: [5, 0, 2, 9, 3] / next est reward: -4.902273178100586
# Ep 3750 | current sol: [5, 0, 2, 9, 3, 4] / next est reward: -4.7449188232421875
# Ep 3750 | current sol: [5, 0, 2, 9, 3, 4, 7] / next est reward: -4.3734235763549805
# Ep 3750 | current sol: [5, 0, 2, 9, 3, 4, 7, 1] / next est reward: -3.7528648376464844
# Ep 3750. Loss = 0.266 / median length = 4.315 / last = 4.2850 / epsilon = 0.1053 / lr = 0.0026
# Ep 3760. Loss = 0.176 / median length = 4.258 / last = 4.9545 / epsilon = 0.1047 / lr = 0.0026
# Ep 3770. Loss = 0.163 / median length = 4.258 / last = 4.0481 / epsilon = 0.1041 / lr = 0.0026
# Ep 3780. Loss = 0.133 / median length = 4.251 / last = 4.5805 / epsilon = 0.1034 / lr = 0.0026
# Ep 3790. Loss = 0.091 / median length = 4.251 / last = 3.6877 / epsilon = 0.1028 / lr = 0.0026
# Ep 3800 | current sol: [0] / next est reward: -4.2506279945373535
# Ep 3800 | current sol: [0, 7] / next est reward: -4.352215766906738
# Ep 3800 | current sol: [0, 7, 3] / next est reward: -4.488883018493652
# Ep 3800 | current sol: [0, 7, 3, 2] / next est reward: -4.634986400604248
# Ep 3800 | current sol: [0, 7, 3, 2, 1] / next est reward: -4.73521089553833
# Ep 3800 | current sol: [0, 7, 3, 2, 1, 8] / next est reward: -4.527993679046631
# Ep 3800 | current sol: [0, 7, 3, 2, 1, 8, 6] / next est reward: -3.732980728149414
# Ep 3800 | current sol: [0, 7, 3, 2, 1, 8, 6, 5] / next est reward: -2.9938721656799316
# Ep 3800 | current sol: [0, 7, 3, 2, 1, 8, 6, 5, 4] / next est reward: -2.1630353927612305
# Ep 3800. Loss = 0.114 / median length = 4.251 / last = 3.6334 / epsilon = 0.1022 / lr = 0.0026
# Ep 3810. Loss = 0.143 / median length = 4.251 / last = 4.7862 / epsilon = 0.1016 / lr = 0.0026
# Ep 3820. Loss = 0.180 / median length = 4.439 / last = 3.6169 / epsilon = 0.1010 / lr = 0.0026
# Ep 3830. Loss = 0.090 / median length = 4.284 / last = 3.6649 / epsilon = 0.1004 / lr = 0.0026
# Ep 3840. Loss = 0.131 / median length = 4.317 / last = 4.3315 / epsilon = 0.1000 / lr = 0.0026
# Ep 3850 | current sol: [8] / next est reward: -3.2700552940368652
# Ep 3850 | current sol: [8, 0] / next est reward: -3.3281617164611816
# Ep 3850 | current sol: [8, 0, 2] / next est reward: -3.4144556522369385
# Ep 3850 | current sol: [8, 0, 2, 5] / next est reward: -3.4820549488067627
# Ep 3850 | current sol: [8, 0, 2, 5, 6, 3, 9] / next est reward: -1.9156090021133423
# Ep 3850 | current sol: [8, 0, 2, 5, 6, 3, 9, 7, 1] / next est reward: -1.6457866430282593
# Ep 3850. Loss = 0.134 / median length = 4.369 / last = 6.2084 / epsilon = 0.1000 / lr = 0.0026
# Ep 3860. Loss = 0.143 / median length = 4.369 / last = 4.2105 / epsilon = 0.1000 / lr = 0.0026
# Ep 3870. Loss = 0.197 / median length = 4.479 / last = 3.8206 / epsilon = 0.1000 / lr = 0.0026
# Ep 3880. Loss = 0.183 / median length = 4.449 / last = 4.5367 / epsilon = 0.1000 / lr = 0.0026
# Ep 3890. Loss = 0.072 / median length = 4.667 / last = 5.2860 / epsilon = 0.1000 / lr = 0.0026
# Ep 3900 | current sol: [6] / next est reward: -3.8168864250183105
# Ep 3900 | current sol: [6, 0] / next est reward: -3.917520046234131
# Ep 3900 | current sol: [6, 0, 2] / next est reward: -4.028176784515381
# Ep 3900 | current sol: [6, 0, 2, 4] / next est reward: -4.145990371704102
# Ep 3900 | current sol: [6, 0, 2, 4, 1] / next est reward: -4.763463497161865
# Ep 3900 | current sol: [6, 0, 2, 4, 1, 8] / next est reward: -4.299655914306641
# Ep 3900 | current sol: [6, 0, 2, 4, 1, 8, 3] / next est reward: -3.824558734893799
# Ep 3900 | current sol: [6, 0, 2, 4, 1, 8, 3, 7] / next est reward: -3.112701416015625
# Ep 3900 | current sol: [6, 0, 2, 4, 1, 8, 3, 7, 5] / next est reward: -2.192568302154541
# Ep 3900. Loss = 0.125 / median length = 4.594 / last = 3.4149 / epsilon = 0.1000 / lr = 0.0026
# Ep 3910. Loss = 0.102 / median length = 4.605 / last = 5.6732 / epsilon = 0.1000 / lr = 0.0026
# Ep 3920. Loss = 0.068 / median length = 4.569 / last = 3.3329 / epsilon = 0.1000 / lr = 0.0026
# Ep 3930. Loss = 0.110 / median length = 4.606 / last = 3.4682 / epsilon = 0.1000 / lr = 0.0026
# Ep 3940. Loss = 0.116 / median length = 4.365 / last = 3.4376 / epsilon = 0.1000 / lr = 0.0026
# Ep 3950 | current sol: [5] / next est reward: -3.627016544342041
# Ep 3950 | current sol: [5, 4] / next est reward: -3.7714786529541016
# Ep 3950 | current sol: [5, 4, 0, 3] / next est reward: -3.634676456451416
# Ep 3950 | current sol: [5, 4, 0, 3, 2] / next est reward: -3.5028040409088135
# Ep 3950 | current sol: [5, 4, 0, 3, 2, 8] / next est reward: -3.506392478942871
# Ep 3950 | current sol: [5, 4, 0, 3, 2, 8, 9] / next est reward: -3.0486435890197754
# Ep 3950 | current sol: [5, 4, 0, 3, 2, 8, 9, 7] / next est reward: -2.2714624404907227
# Ep 3950 | current sol: [5, 4, 0, 3, 2, 8, 9, 7, 1] / next est reward: -2.3473803997039795
# Ep 3950. Loss = 0.086 / median length = 4.477 / last = 4.9974 / epsilon = 0.1000 / lr = 0.0026
# Ep 3960. Loss = 0.142 / median length = 4.365 / last = 5.3855 / epsilon = 0.1000 / lr = 0.0026
# Ep 3970. Loss = 0.086 / median length = 4.215 / last = 2.9183 / epsilon = 0.1000 / lr = 0.0025
# Ep 3980. Loss = 0.153 / median length = 4.339 / last = 4.2978 / epsilon = 0.1000 / lr = 0.0025
# Ep 3990. Loss = 0.062 / median length = 4.237 / last = 2.9611 / epsilon = 0.1000 / lr = 0.0025
# Ep 4000 | current sol: [8] / next est reward: -3.6183743476867676
# Ep 4000 | current sol: [8, 6] / next est reward: -3.6706976890563965
# Ep 4000 | current sol: [8, 6, 4] / next est reward: -3.7647545337677
# Ep 4000 | current sol: [8, 6, 4, 0] / next est reward: -3.750792980194092
# Ep 4000 | current sol: [8, 6, 4, 0, 2] / next est reward: -3.560006618499756
# Ep 4000 | current sol: [8, 6, 4, 0, 2, 5] / next est reward: -3.33764386177063
# Ep 4000 | current sol: [8, 6, 4, 0, 2, 5, 7] / next est reward: -3.8700242042541504
# Ep 4000 | current sol: [8, 6, 4, 0, 2, 5, 7, 3] / next est reward: -3.090559482574463
# Ep 4000 | current sol: [8, 6, 4, 0, 2, 5, 7, 3, 9] / next est reward: -2.0499095916748047
# Ep 4000. Loss = 0.126 / median length = 4.237 / last = 4.7466 / epsilon = 0.1000 / lr = 0.0025

# %% [markdown]
# ## Inspect Training Metrics
# Let's look at the (moving averages of) loss and path length over training.

# %%
def _moving_avg(x, N=10):
    return np.convolve(np.array(x), np.ones((N,))/N, mode='valid')

plt.figure(figsize=(8,5))
plt.semilogy(_moving_avg(losses, 100))
plt.ylabel('loss')
plt.xlabel('training iteration')

plt.figure(figsize=(8,5))
plt.plot(_moving_avg(path_lengths, 100))
plt.ylabel('average length')
plt.xlabel('episode')
# Out:
# Text(0.5, 0, 'episode')

# %% [markdown]
# ## Re-run Best Model and Look at Paths

# %%
""" Get file with smallest distance
"""
all_lengths_fnames = [f for f in os.listdir(FOLDER_NAME) if f.endswith('.tar')]
shortest_fname = sorted(all_lengths_fnames, key=lambda s: float(s.split('.tar')[0].split('_')[-1]))[0]
print('shortest avg length found: {}'.format(shortest_fname.split('.tar')[0].split('_')[-1]))

""" Load checkpoint
"""
Q_func, Q_net, optimizer, lr_scheduler = init_model(os.path.join(FOLDER_NAME, shortest_fname))

""" A function to plot solutions
"""
def plot_solution(coords, mat, solution):
    plt.scatter(coords[:,0], coords[:,1])
    n = len(coords)
    
    for idx in range(n-1):
        i, next_i = solution[idx], solution[idx+1]
        plt.plot([coords[i, 0], coords[next_i, 0]], [coords[i, 1], coords[next_i, 1]], 'k', lw=2, alpha=0.8)
    
    i, next_i = solution[-1], solution[0]
    plt.plot([coords[i, 0], coords[next_i, 0]], [coords[i, 1], coords[next_i, 1]], 'k', lw=2, alpha=0.8)
    plt.plot(coords[solution[0], 0], coords[solution[0], 1], 'x', markersize=10)


    
""" Generate example solutions
"""
NR_NODES = 50
for sample in range(1):
    coords, W_np = get_graph_mat(n=NR_NODES)
    W = torch.tensor(W_np, dtype=torch.float32, requires_grad=False, device=device)
    
    solution = [random.randint(0, NR_NODES-1)]
    current_state = State(partial_solution=solution, W=W, coords=coords)
    current_state_tsr = state2tens(current_state)
    
    while not is_state_final(current_state):
        next_node, est_reward = Q_func.get_best_action(current_state_tsr, 
                                                       current_state)
        
        
        solution = solution + [next_node]
        current_state = State(partial_solution=solution, W=W, coords=coords)
        current_state_tsr = state2tens(current_state)
        
    plt.figure()
    plot_solution(coords, W, solution)
    plt.title('model / len = {}'.format(total_distance(solution, W)))
    
    # for comparison, plot a random solution
    plt.figure()
    random_solution = list(range(NR_NODES))
    plot_solution(coords, W, random_solution)
    plt.title('random / len = {}'.format(total_distance(random_solution, W)))
# Out:
# shortest avg length found: 4.071453243494034
